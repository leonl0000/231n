# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test
from Models.basic_models import average_model
from Models.two_layer_concat import two_layer_concat

set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)


validation = TAVR_3_Frame("__valid")
val_loader = tavr_dataloader(validation, batch_size=16, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train")
train_loader = tavr_dataloader(training, batch_size=8, shuffle=True, num_workers=2)


ave_model = average_model()
model = two_layer_concat(standardize_slice=True)
loss_fn = batch_l2_loss()
# Out:
# using device: cpu

# %%
learning_rate = 1e-2
momentum = 0.95
reg = 1e-7

optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=reg, nesterov=True)

# %%
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3, lr_decay=0.5)
# Out:
# ****Epoch 0 Iteration 0, loss = 0.1929
# Validation loss 0.2036 over 81 frames
# conv_a1.weight,   	norm: 3.5382e+00, 	grad norm: 8.6264e-02 	Update/norm: 2.4381e-04
# conv_a1.bias,   	norm: 2.4112e-01, 	grad norm: 6.3877e-04 	Update/norm: 2.6492e-05
# conv_b1.weight,   	norm: 4.0168e+00, 	grad norm: 4.6601e-02 	Update/norm: 1.1602e-04
# conv_b1.bias,   	norm: 2.7696e-01, 	grad norm: 2.5704e-04 	Update/norm: 9.2809e-06
# final.weight,   	norm: 1.2826e+00, 	grad norm: 9.8121e-02 	Update/norm: 7.6503e-04
# final.bias,   	norm: 8.4410e-03, 	grad norm: 6.6248e-04 	Update/norm: 7.8484e-04
#
# Iter 0... ... .... ...
# Iter 20... ... ...
# Iteration 30, loss = 0.1760
# Validation loss 0.1931 over 81 frames
# conv_a1.weight,   	norm: 3.5296e+00, 	grad norm: 2.2935e-02 	Update/norm: 5.0267e-05
# conv_a1.bias,   	norm: 2.4120e-01, 	grad norm: 1.2751e-04 	Update/norm: 4.0896e-06
# conv_b1.weight,   	norm: 4.0169e+00, 	grad norm: 1.9337e-02 	Update/norm: 3.7239e-05
# conv_b1.bias,   	norm: 2.7688e-01, 	grad norm: 1.7821e-04 	Update/norm: 4.9790e-06
# final.weight,   	norm: 1.2551e+00, 	grad norm: 3.2849e-02 	Update/norm: 2.0246e-04
# final.bias,   	norm: 8.6803e-03, 	grad norm: 4.0120e-04 	Update/norm: 3.5754e-04
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.1825
# Validation loss 0.1910 over 81 frames
# conv_a1.weight,   	norm: 3.5211e+00, 	grad norm: 6.5063e-02 	Update/norm: 1.1058e-04
# conv_a1.bias,   	norm: 2.4118e-01, 	grad norm: 1.6720e-04 	Update/norm: 4.1487e-06
# conv_b1.weight,   	norm: 4.0172e+00, 	grad norm: 4.0802e-02 	Update/norm: 6.0781e-05
# conv_b1.bias,   	norm: 2.7666e-01, 	grad norm: 1.5198e-04 	Update/norm: 3.2874e-06
# final.weight,   	norm: 1.2244e+00, 	grad norm: 5.6341e-02 	Update/norm: 2.7537e-04
# final.bias,   	norm: 9.9848e-03, 	grad norm: 4.3817e-04 	Update/norm: 2.6262e-04
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 1 Iteration 0, loss = 0.1757
# Validation loss 0.1905 over 81 frames
# conv_a1.weight,   	norm: 3.5181e+00, 	grad norm: 4.7445e-02 	Update/norm: 6.7430e-05
# conv_a1.bias,   	norm: 2.4118e-01, 	grad norm: 4.2025e-04 	Update/norm: 8.7124e-06
# conv_b1.weight,   	norm: 4.0167e+00, 	grad norm: 3.0364e-02 	Update/norm: 3.7797e-05
# conv_b1.bias,   	norm: 2.7658e-01, 	grad norm: 2.3562e-04 	Update/norm: 4.2596e-06
# final.weight,   	norm: 1.2090e+00, 	grad norm: 5.2500e-02 	Update/norm: 2.1713e-04
# final.bias,   	norm: 1.0479e-02, 	grad norm: 6.9372e-04 	Update/norm: 3.3099e-04
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 0.1906
# Validation loss 0.1906 over 81 frames
# conv_a1.weight,   	norm: 3.5155e+00, 	grad norm: 1.9523e-02 	Update/norm: 2.1480e-05
# conv_a1.bias,   	norm: 2.4119e-01, 	grad norm: 8.1730e-05 	Update/norm: 1.3107e-06
# conv_b1.weight,   	norm: 4.0160e+00, 	grad norm: 1.3652e-02 	Update/norm: 1.3148e-05
# conv_b1.bias,   	norm: 2.7650e-01, 	grad norm: 9.1300e-05 	Update/norm: 1.2772e-06
# final.weight,   	norm: 1.1936e+00, 	grad norm: 2.5942e-02 	Update/norm: 8.4064e-05
# final.bias,   	norm: 1.0944e-02, 	grad norm: 3.3677e-04 	Update/norm: 1.1902e-04
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.1879
# Validation loss 0.1898 over 81 frames
# conv_a1.weight,   	norm: 3.5137e+00, 	grad norm: 1.5477e-02 	Update/norm: 1.3180e-05
# conv_a1.bias,   	norm: 2.4120e-01, 	grad norm: 8.1784e-05 	Update/norm: 1.0146e-06
# conv_b1.weight,   	norm: 4.0155e+00, 	grad norm: 1.7332e-02 	Update/norm: 1.2915e-05
# conv_b1.bias,   	norm: 2.7644e-01, 	grad norm: 1.3926e-04 	Update/norm: 1.5074e-06
# final.weight,   	norm: 1.1820e+00, 	grad norm: 3.5221e-02 	Update/norm: 8.9162e-05
# final.bias,   	norm: 1.1359e-02, 	grad norm: 4.4077e-04 	Update/norm: 1.1610e-04
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 2 Iteration 0, loss = 0.1721
# Validation loss 0.1899 over 81 frames
# conv_a1.weight,   	norm: 3.5128e+00, 	grad norm: 3.2424e-02 	Update/norm: 2.3076e-05
# conv_a1.bias,   	norm: 2.4120e-01, 	grad norm: 1.2766e-04 	Update/norm: 1.3231e-06
# conv_b1.weight,   	norm: 4.0151e+00, 	grad norm: 2.1888e-02 	Update/norm: 1.3628e-05
# conv_b1.bias,   	norm: 2.7641e-01, 	grad norm: 1.1722e-04 	Update/norm: 1.0602e-06
# final.weight,   	norm: 1.1755e+00, 	grad norm: 3.9574e-02 	Update/norm: 8.4161e-05
# final.bias,   	norm: 1.1612e-02, 	grad norm: 4.5350e-04 	Update/norm: 9.7632e-05
#
# Iter 0... ... ...
# Iter 10... ..... .
# Iteration 30, loss = 0.1678
# Validation loss 0.1896 over 81 frames
# conv_a1.weight,   	norm: 3.5119e+00, 	grad norm: 8.6035e-03 	Update/norm: 4.7378e-06
# conv_a1.bias,   	norm: 2.4121e-01, 	grad norm: 1.6220e-04 	Update/norm: 1.3005e-06
# conv_b1.weight,   	norm: 4.0147e+00, 	grad norm: 6.9405e-03 	Update/norm: 3.3434e-06
# conv_b1.bias,   	norm: 2.7638e-01, 	grad norm: 9.5884e-05 	Update/norm: 6.7094e-07
# final.weight,   	norm: 1.1685e+00, 	grad norm: 1.2378e-02 	Update/norm: 2.0487e-05
# final.bias,   	norm: 1.1773e-02, 	grad norm: 3.1484e-04 	Update/norm: 5.1720e-05
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.1757
# Validation loss 0.1897 over 81 frames
# conv_a1.weight,   	norm: 3.5113e+00, 	grad norm: 1.3832e-02 	Update/norm: 5.8933e-06
# conv_a1.bias,   	norm: 2.4122e-01, 	grad norm: 2.5645e-04 	Update/norm: 1.5906e-06
# conv_b1.weight,   	norm: 4.0143e+00, 	grad norm: 1.2542e-02 	Update/norm: 4.6744e-06
# conv_b1.bias,   	norm: 2.7636e-01, 	grad norm: 2.2010e-04 	Update/norm: 1.1916e-06
# final.weight,   	norm: 1.1631e+00, 	grad norm: 2.8678e-02 	Update/norm: 3.6888e-05
# final.bias,   	norm: 1.1962e-02, 	grad norm: 8.2423e-04 	Update/norm: 1.0308e-04
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80

# %%
# One last test + visualize results on 1 validation sequence
val_seq = TAVR_Sequence("__valid")
test(model, val_loader, loss_fn, device)
test(ave_model, val_loader, loss_fn, device)

with torch.no_grad():
    model.eval()
    ave_frames = [val_seq[0][0]]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:], val_seq[0][i][None,:]))
        ave_frames += [ave_frame[0][0],  val_seq[0][i]]
    ave_frames += [val_seq[0][9]]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# Validation loss 0.1894 over 81 frames
# Validation loss 0.0047 over 81 frames
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
