# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss, batch_mse_loss
from utils.run_model import train, test
from Models.basic_models import average_model, two_layer_basic


set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)

validation = TAVR_3_Frame("__valid")
val_loader = tavr_dataloader(validation, batch_size=4, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train")
train_loader = tavr_dataloader(training, batch_size=8, shuffle=True, num_workers=2)

ave_model = average_model()
model = two_layer_basic()
loss_fn = batch_mse_loss()
# Out:
# using device: cpu

# %%
learning_rate = 1e-9
momentum = 0.90
reg = 1e-7

optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=reg, nesterov=True)

# %%
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3, lr_decay=0.8)
# Out:
# ****Epoch 0 Iteration 0, loss = 2867194.0000
# Validation loss 1855314.7500 over 81 frames
# conv_a1.weight,   	norm: 4.0547e+00, 	update norm: 2.0319e-02 	Update/norm: 5.0113e-03
# conv_a1.bias,   	norm: 3.5418e-01, 	update norm: 3.6393e-06 	Update/norm: 1.0275e-05
# conv_b1.weight,   	norm: 4.4036e+00, 	update norm: 2.2452e-02 	Update/norm: 5.0986e-03
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 3.9947e-06 	Update/norm: 1.2779e-05
# final.weight,   	norm: 1.3378e+00, 	update norm: 2.3918e-02 	Update/norm: 1.7878e-02
# final.bias,   	norm: 1.7159e-01, 	update norm: 5.7071e-06 	Update/norm: 3.3260e-05
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 30161.8516
# Validation loss 24936.6250 over 81 frames
# conv_a1.weight,   	norm: 4.0332e+00, 	update norm: 2.9643e-03 	Update/norm: 7.3497e-04
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.0115e-07 	Update/norm: 1.6974e-06
# conv_b1.weight,   	norm: 4.4112e+00, 	update norm: 2.9510e-03 	Update/norm: 6.6898e-04
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 6.2041e-07 	Update/norm: 1.9847e-06
# final.weight,   	norm: 1.2765e+00, 	update norm: 3.5253e-03 	Update/norm: 2.7616e-03
# final.bias,   	norm: 1.7154e-01, 	update norm: 1.0729e-06 	Update/norm: 6.2543e-06
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 19164.6445
# Validation loss 20277.0527 over 81 frames
# conv_a1.weight,   	norm: 4.0312e+00, 	update norm: 4.6271e-04 	Update/norm: 1.1478e-04
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 1.2818e-07 	Update/norm: 3.6194e-07
# conv_b1.weight,   	norm: 4.4105e+00, 	update norm: 4.1474e-04 	Update/norm: 9.4033e-05
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 1.2226e-07 	Update/norm: 3.9110e-07
# final.weight,   	norm: 1.2661e+00, 	update norm: 6.5322e-04 	Update/norm: 5.1591e-04
# final.bias,   	norm: 1.7154e-01, 	update norm: 2.0862e-07 	Update/norm: 1.2162e-06
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 1 Iteration 0, loss = 18699.1074
# Validation loss 19108.0801 over 81 frames
# conv_a1.weight,   	norm: 4.0306e+00, 	update norm: 2.5468e-04 	Update/norm: 6.3186e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 7.0682e-08 	Update/norm: 1.9958e-07
# conv_b1.weight,   	norm: 4.4099e+00, 	update norm: 3.0395e-04 	Update/norm: 6.8925e-05
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 6.0986e-08 	Update/norm: 1.9509e-07
# final.weight,   	norm: 1.2619e+00, 	update norm: 5.0336e-04 	Update/norm: 3.9887e-04
# final.bias,   	norm: 1.7153e-01, 	update norm: 1.1921e-07 	Update/norm: 6.9496e-07
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 20077.1797
# Validation loss 17889.6543 over 81 frames
# conv_a1.weight,   	norm: 4.0299e+00, 	update norm: 2.2583e-04 	Update/norm: 5.6038e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.4953e-08 	Update/norm: 1.8340e-07
# conv_b1.weight,   	norm: 4.4091e+00, 	update norm: 2.6689e-04 	Update/norm: 6.0533e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 5.5755e-08 	Update/norm: 1.7836e-07
# final.weight,   	norm: 1.2569e+00, 	update norm: 4.4743e-04 	Update/norm: 3.5598e-04
# final.bias,   	norm: 1.7153e-01, 	update norm: 1.0431e-07 	Update/norm: 6.0810e-07
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 17341.9121
# Validation loss 16794.9512 over 81 frames
# conv_a1.weight,   	norm: 4.0294e+00, 	update norm: 1.8539e-04 	Update/norm: 4.6010e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 5.4241e-08 	Update/norm: 1.5316e-07
# conv_b1.weight,   	norm: 4.4084e+00, 	update norm: 2.2217e-04 	Update/norm: 5.0397e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 5.2815e-08 	Update/norm: 1.6896e-07
# final.weight,   	norm: 1.2527e+00, 	update norm: 3.7317e-04 	Update/norm: 2.9790e-04
# final.bias,   	norm: 1.7153e-01, 	update norm: 8.9407e-08 	Update/norm: 5.2124e-07
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 2 Iteration 0, loss = 16839.0332
# Validation loss 16168.8105 over 81 frames
# conv_a1.weight,   	norm: 4.0290e+00, 	update norm: 1.8203e-04 	Update/norm: 4.5179e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 5.4241e-08 	Update/norm: 1.5316e-07
# conv_b1.weight,   	norm: 4.4080e+00, 	update norm: 2.0734e-04 	Update/norm: 4.7037e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 5.2815e-08 	Update/norm: 1.6896e-07
# final.weight,   	norm: 1.2501e+00, 	update norm: 3.5022e-04 	Update/norm: 2.8014e-04
# final.bias,   	norm: 1.7153e-01, 	update norm: 8.9407e-08 	Update/norm: 5.2124e-07
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 17616.3984
# Validation loss 15333.9062 over 81 frames
# conv_a1.weight,   	norm: 4.0286e+00, 	update norm: 1.5182e-04 	Update/norm: 3.7686e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 4.1483e-08 	Update/norm: 1.1713e-07
# conv_b1.weight,   	norm: 4.4074e+00, 	update norm: 1.8405e-04 	Update/norm: 4.1759e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 3.8714e-08 	Update/norm: 1.2385e-07
# final.weight,   	norm: 1.2469e+00, 	update norm: 3.1020e-04 	Update/norm: 2.4878e-04
# final.bias,   	norm: 1.7152e-01, 	update norm: 7.4506e-08 	Update/norm: 4.3438e-07
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 14576.4062
# Validation loss 14704.6426 over 81 frames
# conv_a1.weight,   	norm: 4.0282e+00, 	update norm: 1.2964e-04 	Update/norm: 3.2182e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 4.1483e-08 	Update/norm: 1.1713e-07
# conv_b1.weight,   	norm: 4.4070e+00, 	update norm: 1.6119e-04 	Update/norm: 3.6575e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 3.7991e-08 	Update/norm: 1.2153e-07
# final.weight,   	norm: 1.2442e+00, 	update norm: 2.6813e-04 	Update/norm: 2.1551e-04
# final.bias,   	norm: 1.7152e-01, 	update norm: 7.4506e-08 	Update/norm: 4.3438e-07
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80

# %%
# INCREASE the learning rate, stop lr decay, train 3 more epochs

optimizer.param_groups[0]['lr'] = 1e-8
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3)
# Out:
# ****Epoch 0 Iteration 0, loss = 12612.5488
# Validation loss 14005.6084 over 81 frames
# conv_a1.weight,   	norm: 4.0280e+00, 	update norm: 2.2825e-03 	Update/norm: 5.6666e-04
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.5345e-07 	Update/norm: 1.8451e-06
# conv_b1.weight,   	norm: 4.4067e+00, 	update norm: 2.9340e-03 	Update/norm: 6.6579e-04
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 6.6998e-07 	Update/norm: 2.1433e-06
# final.weight,   	norm: 1.2425e+00, 	update norm: 4.8132e-03 	Update/norm: 3.8739e-03
# final.bias,   	norm: 1.7152e-01, 	update norm: 1.1921e-06 	Update/norm: 6.9501e-06
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 8148.6157
# Validation loss 7678.6895 over 81 frames
# conv_a1.weight,   	norm: 4.0238e+00, 	update norm: 1.3501e-03 	Update/norm: 3.3554e-04
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 3.2476e-07 	Update/norm: 9.1702e-07
# conv_b1.weight,   	norm: 4.4014e+00, 	update norm: 1.9017e-03 	Update/norm: 4.3207e-04
# conv_b1.bias,   	norm: 3.1261e-01, 	update norm: 4.7188e-07 	Update/norm: 1.5095e-06
# final.weight,   	norm: 1.2107e+00, 	update norm: 2.9374e-03 	Update/norm: 2.4262e-03
# final.bias,   	norm: 1.7149e-01, 	update norm: 7.4506e-07 	Update/norm: 4.3446e-06
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 4839.1177
# Validation loss 5804.4287 over 81 frames
# conv_a1.weight,   	norm: 4.0220e+00, 	update norm: 7.2860e-04 	Update/norm: 1.8115e-04
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 1.0668e-07 	Update/norm: 3.0122e-07
# conv_b1.weight,   	norm: 4.3992e+00, 	update norm: 1.0811e-03 	Update/norm: 2.4575e-04
# conv_b1.bias,   	norm: 3.1261e-01, 	update norm: 2.3455e-07 	Update/norm: 7.5028e-07
# final.weight,   	norm: 1.1971e+00, 	update norm: 1.5259e-03 	Update/norm: 1.2746e-03
# final.bias,   	norm: 1.7148e-01, 	update norm: 2.8312e-07 	Update/norm: 1.6511e-06
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 1 Iteration 0, loss = 4615.3101
# Validation loss 5280.3848 over 81 frames
# conv_a1.weight,   	norm: 4.0213e+00, 	update norm: 5.4117e-04 	Update/norm: 1.3458e-04
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 3.5732e-08 	Update/norm: 1.0089e-07
# conv_b1.weight,   	norm: 4.3981e+00, 	update norm: 7.7500e-04 	Update/norm: 1.7621e-04
# conv_b1.bias,   	norm: 3.1261e-01, 	update norm: 1.5292e-07 	Update/norm: 4.8917e-07
# final.weight,   	norm: 1.1910e+00, 	update norm: 1.0711e-03 	Update/norm: 8.9933e-04
# final.bias,   	norm: 1.7147e-01, 	update norm: 8.9407e-08 	Update/norm: 5.2141e-07
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 4593.0693
# Validation loss 4845.8198 over 81 frames
# conv_a1.weight,   	norm: 4.0204e+00, 	update norm: 4.2722e-04 	Update/norm: 1.0626e-04
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 4.5320e-08 	Update/norm: 1.2797e-07
# conv_b1.weight,   	norm: 4.3967e+00, 	update norm: 6.1970e-04 	Update/norm: 1.4095e-04
# conv_b1.bias,   	norm: 3.1261e-01, 	update norm: 1.2974e-07 	Update/norm: 4.1504e-07
# final.weight,   	norm: 1.1830e+00, 	update norm: 7.9798e-04 	Update/norm: 6.7454e-04
# final.bias,   	norm: 1.7147e-01, 	update norm: 2.9802e-08 	Update/norm: 1.7380e-07
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 3803.5295
# Validation loss 4550.5371 over 81 frames
# conv_a1.weight,   	norm: 4.0197e+00, 	update norm: 3.3067e-04 	Update/norm: 8.2261e-05
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 6.0069e-08 	Update/norm: 1.6961e-07
# conv_b1.weight,   	norm: 4.3954e+00, 	update norm: 5.0728e-04 	Update/norm: 1.1541e-04
# conv_b1.bias,   	norm: 3.1261e-01, 	update norm: 1.2737e-07 	Update/norm: 4.0744e-07
# final.weight,   	norm: 1.1757e+00, 	update norm: 5.7447e-04 	Update/norm: 4.8862e-04
# final.bias,   	norm: 1.7147e-01, 	update norm: 1.0431e-07 	Update/norm: 6.0831e-07
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 2 Iteration 0, loss = 3877.2556
# Validation loss 4399.7373 over 81 frames
# conv_a1.weight,   	norm: 4.0192e+00, 	update norm: 2.8677e-04 	Update/norm: 7.1348e-05
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 6.7878e-08 	Update/norm: 1.9166e-07
# conv_b1.weight,   	norm: 4.3946e+00, 	update norm: 4.9888e-04 	Update/norm: 1.1352e-04
# conv_b1.bias,   	norm: 3.1261e-01, 	update norm: 1.2495e-07 	Update/norm: 3.9970e-07
# final.weight,   	norm: 1.1709e+00, 	update norm: 5.4889e-04 	Update/norm: 4.6878e-04
# final.bias,   	norm: 1.7148e-01, 	update norm: 1.3411e-07 	Update/norm: 7.8210e-07
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 4019.1860
# Validation loss 4223.5737 over 81 frames
# conv_a1.weight,   	norm: 4.0186e+00, 	update norm: 2.8860e-04 	Update/norm: 7.1814e-05
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 7.0682e-08 	Update/norm: 1.9958e-07
# conv_b1.weight,   	norm: 4.3933e+00, 	update norm: 4.3797e-04 	Update/norm: 9.9690e-05
# conv_b1.bias,   	norm: 3.1261e-01, 	update norm: 1.2495e-07 	Update/norm: 3.9971e-07
# final.weight,   	norm: 1.1641e+00, 	update norm: 4.7690e-04 	Update/norm: 4.0969e-04
# final.bias,   	norm: 1.7148e-01, 	update norm: 1.6391e-07 	Update/norm: 9.5588e-07
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 4065.6033
# Validation loss 4052.6841 over 81 frames
# conv_a1.weight,   	norm: 4.0181e+00, 	update norm: 3.2074e-04 	Update/norm: 7.9823e-05
# conv_a1.bias,   	norm: 3.5415e-01, 	update norm: 7.0682e-08 	Update/norm: 1.9958e-07
# conv_b1.weight,   	norm: 4.3922e+00, 	update norm: 4.1119e-04 	Update/norm: 9.3618e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 1.2083e-07 	Update/norm: 3.8652e-07
# final.weight,   	norm: 1.1577e+00, 	update norm: 4.8116e-04 	Update/norm: 4.1564e-04
# final.bias,   	norm: 1.7148e-01, 	update norm: 1.6391e-07 	Update/norm: 9.5585e-07
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80

# %%
# One last test + visualize results on 1 validation sequence
val_seq = TAVR_Sequence("__valid")
test(model, val_loader, loss_fn, device)
test(ave_model, val_loader, loss_fn, device)

with torch.no_grad():
    model.eval()
    ave_frames = [val_seq[0][0]]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:], val_seq[0][i][None,:]))
        ave_frames += [ave_frame[0][0],  val_seq[0][i]]
    ave_frames += [val_seq[0][9]]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# Validation loss 3955.5393 over 81 frames
# Validation loss 1416.3076 over 81 frames
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3)
# Out:
# ****Epoch 0 Iteration 0, loss = 4787.1558
# Validation loss 3957.7974 over 81 frames
# conv_a1.weight,   	norm: 4.0177e+00, 	update norm: 2.7830e-04 	Update/norm: 6.9269e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.3220e-08 	Update/norm: 1.7851e-07
# conv_b1.weight,   	norm: 4.3913e+00, 	update norm: 3.9429e-04 	Update/norm: 8.9789e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 1.0880e-07 	Update/norm: 3.4805e-07
# final.weight,   	norm: 1.1533e+00, 	update norm: 4.7102e-04 	Update/norm: 4.0841e-04
# final.bias,   	norm: 1.7149e-01, 	update norm: 1.3411e-07 	Update/norm: 7.8204e-07
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 3840.4497
# Validation loss 3822.2583 over 81 frames
# conv_a1.weight,   	norm: 4.0172e+00, 	update norm: 2.4412e-04 	Update/norm: 6.0767e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.6222e-08 	Update/norm: 1.8699e-07
# conv_b1.weight,   	norm: 4.3903e+00, 	update norm: 3.7487e-04 	Update/norm: 8.5386e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 1.1051e-07 	Update/norm: 3.5352e-07
# final.weight,   	norm: 1.1475e+00, 	update norm: 4.2084e-04 	Update/norm: 3.6674e-04
# final.bias,   	norm: 1.7149e-01, 	update norm: 1.7881e-07 	Update/norm: 1.0427e-06
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 3782.1904
# Validation loss 3696.8350 over 81 frames
# conv_a1.weight,   	norm: 4.0168e+00, 	update norm: 2.2422e-04 	Update/norm: 5.5821e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.6222e-08 	Update/norm: 1.8699e-07
# conv_b1.weight,   	norm: 4.3892e+00, 	update norm: 3.6539e-04 	Update/norm: 8.3246e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 1.0674e-07 	Update/norm: 3.4146e-07
# final.weight,   	norm: 1.1421e+00, 	update norm: 4.0442e-04 	Update/norm: 3.5409e-04
# final.bias,   	norm: 1.7150e-01, 	update norm: 1.7881e-07 	Update/norm: 1.0427e-06
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 1 Iteration 0, loss = 4841.7520
# Validation loss 3648.7866 over 81 frames
# conv_a1.weight,   	norm: 4.0165e+00, 	update norm: 2.8272e-04 	Update/norm: 7.0389e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 4.8857e-08 	Update/norm: 1.3795e-07
# conv_b1.weight,   	norm: 4.3885e+00, 	update norm: 3.3488e-04 	Update/norm: 7.6308e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 9.8632e-08 	Update/norm: 3.1553e-07
# final.weight,   	norm: 1.1384e+00, 	update norm: 4.0898e-04 	Update/norm: 3.5927e-04
# final.bias,   	norm: 1.7150e-01, 	update norm: 1.3411e-07 	Update/norm: 7.8198e-07
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 3163.7256
# Validation loss 3537.8569 over 81 frames
# conv_a1.weight,   	norm: 4.0161e+00, 	update norm: 2.0210e-04 	Update/norm: 5.0322e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.2336e-08 	Update/norm: 1.7601e-07
# conv_b1.weight,   	norm: 4.3876e+00, 	update norm: 3.1717e-04 	Update/norm: 7.2288e-05
# conv_b1.bias,   	norm: 3.1260e-01, 	update norm: 8.9794e-08 	Update/norm: 2.8725e-07
# final.weight,   	norm: 1.1335e+00, 	update norm: 3.4709e-04 	Update/norm: 3.0621e-04
# final.bias,   	norm: 1.7151e-01, 	update norm: 1.4901e-07 	Update/norm: 8.6885e-07
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 3700.6455
# Validation loss 3456.6233 over 81 frames
# conv_a1.weight,   	norm: 4.0158e+00, 	update norm: 1.8764e-04 	Update/norm: 4.6726e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 6.6222e-08 	Update/norm: 1.8698e-07
# conv_b1.weight,   	norm: 4.3868e+00, 	update norm: 3.5367e-04 	Update/norm: 8.0621e-05
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 9.3726e-08 	Update/norm: 2.9983e-07
# final.weight,   	norm: 1.1290e+00, 	update norm: 3.8828e-04 	Update/norm: 3.4392e-04
# final.bias,   	norm: 1.7151e-01, 	update norm: 1.6391e-07 	Update/norm: 9.5571e-07
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 2 Iteration 0, loss = 3122.3291
# Validation loss 3399.5544 over 81 frames
# conv_a1.weight,   	norm: 4.0155e+00, 	update norm: 2.4383e-04 	Update/norm: 6.0721e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 4.4078e-08 	Update/norm: 1.2446e-07
# conv_b1.weight,   	norm: 4.3862e+00, 	update norm: 3.1763e-04 	Update/norm: 7.2415e-05
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 9.0333e-08 	Update/norm: 2.8898e-07
# final.weight,   	norm: 1.1258e+00, 	update norm: 3.1745e-04 	Update/norm: 2.8198e-04
# final.bias,   	norm: 1.7151e-01, 	update norm: 1.0431e-07 	Update/norm: 6.0817e-07
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 3928.2573
# Validation loss 3344.8909 over 81 frames
# conv_a1.weight,   	norm: 4.0152e+00, 	update norm: 2.1004e-04 	Update/norm: 5.2312e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 4.4078e-08 	Update/norm: 1.2446e-07
# conv_b1.weight,   	norm: 4.3854e+00, 	update norm: 2.8963e-04 	Update/norm: 6.6043e-05
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 7.4506e-08 	Update/norm: 2.3835e-07
# final.weight,   	norm: 1.1216e+00, 	update norm: 3.3415e-04 	Update/norm: 2.9791e-04
# final.bias,   	norm: 1.7152e-01, 	update norm: 1.0431e-07 	Update/norm: 6.0815e-07
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 3076.2273
# Validation loss 3270.1084 over 81 frames
# conv_a1.weight,   	norm: 4.0149e+00, 	update norm: 1.8706e-04 	Update/norm: 4.6591e-05
# conv_a1.bias,   	norm: 3.5416e-01, 	update norm: 4.4703e-08 	Update/norm: 1.2622e-07
# conv_b1.weight,   	norm: 4.3847e+00, 	update norm: 2.7461e-04 	Update/norm: 6.2628e-05
# conv_b1.bias,   	norm: 3.1259e-01, 	update norm: 7.9899e-08 	Update/norm: 2.5560e-07
# final.weight,   	norm: 1.1177e+00, 	update norm: 2.8638e-04 	Update/norm: 2.5622e-04
# final.bias,   	norm: 1.7152e-01, 	update norm: 1.3411e-07 	Update/norm: 7.8190e-07
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80

# %%
test(model, val_loader, loss_fn, device)
test(ave_model, val_loader, loss_fn, device)

with torch.no_grad():
    model.eval()
    ave_frames = [val_seq[0][0]]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:], val_seq[0][i][None,:]))
        ave_frames += [ave_frame[0][0],  val_seq[0][i]]
    ave_frames += [val_seq[0][9]]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# Validation loss 3231.1897 over 81 frames
# Validation loss 1429.3865 over 81 frames
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
