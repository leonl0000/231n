# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test
from Models.basic_models import average_model, two_layer_basic


set_figsize(20, 15)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
# Constant to control how frequently we print train loss
print_every = 100
print('using device:', device)
# Out:
# using device: cpu

# %%
validation = TAVR_3_Frame("__valid")
val_loader = tavr_dataloader(validation, batch_size=4, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train")
train_loader = tavr_dataloader(training, batch_size=4, shuffle=True, num_workers=2)

# %%
ave_model = average_model()
basic_model = two_layer_basic()
l2_loss = batch_l2_loss()

# %%
learning_rate = 1e-3
momentum = 0.95
reg = 1e-1

optimizer = optim.SGD(basic_model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=reg, nesterov=True)

# %%
train(basic_model, optimizer, train_loader, val_loader, 
         l2_loss, device, 
         print_every=15)
# Out:
# Time 0
# Epoch 0 Iteration 0, loss = 0.6077
# Validation loss 0.5955 over 81 frames
#
# Time 1
# Time 2
# Time 3
# Time 4
# Time 5
# Time 6
# Time 7
# Time 8
# Time 9
# Time 10
# Time 11
# Time 12
# Time 13
# Time 14
# Time 15
# Iteration 15, loss = 0.2266
# Validation loss 0.2265 over 81 frames
#
# Time 16
# Time 17
# Time 18
# Time 19
# Time 20
# Time 21
# Time 22
# Time 23
# Time 24
# Time 25
# Time 26
# Time 27
# Time 28
# Time 29
# Time 30
# Iteration 30, loss = 0.2751
# Validation loss 0.2541 over 81 frames
#
# Time 31
# Time 32
# Time 33
# Time 34
# Time 35
# Time 36
# Time 37
# Time 38
# Time 39
# Time 40
# Time 41
# Time 42
# Time 43
# Time 44
# Time 45
# Iteration 45, loss = 0.2605
# Validation loss 0.2466 over 81 frames
#
# Time 46
# Time 47
# Time 48
# Time 49
# Time 50
# Time 51
# Time 52
# Time 53
# Time 54
# Time 55
# Time 56
# Time 57
# Time 58
# Time 59
# Time 60
# Iteration 60, loss = 0.2377
# Validation loss 0.2287 over 81 frames
#
# Time 61
# Time 62
# Time 63
# Time 64
# Time 65
# Time 66
# Time 67
# Time 68
# Time 69
# Time 70
# Time 71
# Time 72
# Time 73
# Time 74
# Time 75
# Iteration 75, loss = 0.2255
# Validation loss 0.2307 over 81 frames
#
# Time 76
# Time 77
# Time 78
# Time 79
# Time 80
# Time 81
# Time 82
# Time 83
# Time 84
# Time 85
# Time 86
# Time 87
# Time 88
# Time 89
# Time 90
# Iteration 90, loss = 0.2568
# Validation loss 0.2185 over 81 frames
#
# Time 91
# Time 92
# Time 93
# Time 94
# Time 95
# Time 96
# Time 97
# Time 98
# Time 99
# Time 100
# Time 101
# Time 102
# Time 103
# Time 104
# Time 105
# Iteration 105, loss = 0.2348
# Validation loss 0.2230 over 81 frames
#
# Time 106
# Time 107
# Time 108
# Time 109
# Time 110
# Time 111
# Time 112
# Time 113
# Time 114
# Time 115
# Time 116
# Time 117
# Time 118
# Time 119
# Time 120
# Iteration 120, loss = 0.2257
# Validation loss 0.2160 over 81 frames
#
# Time 121
# Time 122
# Time 123
# Time 124
# Time 125
# Time 126
# Time 127
# Time 128
# Time 129
# Time 130
# Time 131
# Time 132
# Time 133
# Time 134
# Time 135
# Iteration 135, loss = 0.2270
# Validation loss 0.2269 over 81 frames
#
# Time 136
# Time 137
# Time 138
# Time 139
# Process Process-6:
# Process Process-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
