# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test
from Models.basic_models import average_model, two_layer_basic


set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)

validation = TAVR_3_Frame("__valid")
val_loader = tavr_dataloader(validation, batch_size=16, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train")
train_loader = tavr_dataloader(training, batch_size=8, shuffle=True, num_workers=2)

ave_model = average_model()
model = two_layer_basic()
loss_fn = batch_l2_loss()
# Out:
# using device: cpu

# %%
learning_rate = 3e-2
momentum = 0.95
reg = 1e-7

optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=reg, nesterov=True)

# %%
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=20, print_level=3, lr_decay=0.8)
# Out:
# Epoch 0 Iteration 0, loss = 0.9437
# Validation loss 0.5034 over 81 frames
# conv_a1.weight,   	norm: 4.4730e+00, 	grad norm: 2.1017e+00 	Update/norm: 1.4096e-02
# conv_a1.bias,   	norm: 3.0121e-01, 	grad norm: 3.3348e-04 	Update/norm: 3.3213e-05
# conv_b1.weight,   	norm: 4.2313e+00, 	grad norm: 8.4670e-01 	Update/norm: 6.0031e-03
# conv_b1.bias,   	norm: 2.2076e-01, 	grad norm: 1.3995e-04 	Update/norm: 1.9019e-05
# final.weight,   	norm: 1.3442e+00, 	grad norm: 1.7954e+00 	Update/norm: 4.0069e-02
# final.bias,   	norm: 1.7827e-01, 	grad norm: 2.9334e-04 	Update/norm: 4.9364e-05
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iteration 20, loss = 0.2520
# Validation loss 0.2476 over 81 frames
# conv_a1.weight,   	norm: 4.4771e+00, 	grad norm: 1.6911e-02 	Update/norm: 1.0724e-04
# conv_a1.bias,   	norm: 3.0143e-01, 	grad norm: 7.8764e-05 	Update/norm: 7.4187e-06
# conv_b1.weight,   	norm: 4.2167e+00, 	grad norm: 1.7075e-02 	Update/norm: 1.1497e-04
# conv_b1.bias,   	norm: 2.2069e-01, 	grad norm: 3.4143e-05 	Update/norm: 4.3926e-06
# final.weight,   	norm: 1.0363e+00, 	grad norm: 2.7348e-02 	Update/norm: 7.4925e-04
# final.bias,   	norm: 1.7892e-01, 	grad norm: 1.4390e-04 	Update/norm: 2.2834e-05
#
# Iter 20... ... ...
# Iter 30... ... ...
# Iteration 40, loss = 0.2349
# Validation loss 0.2330 over 81 frames
# conv_a1.weight,   	norm: 4.5060e+00, 	grad norm: 1.5367e-02 	Update/norm: 9.1635e-05
# conv_a1.bias,   	norm: 3.0179e-01, 	grad norm: 5.6193e-05 	Update/norm: 5.0031e-06
# conv_b1.weight,   	norm: 4.2118e+00, 	grad norm: 1.3400e-02 	Update/norm: 8.5485e-05
# conv_b1.bias,   	norm: 2.2063e-01, 	grad norm: 4.0037e-05 	Update/norm: 4.8759e-06
# final.weight,   	norm: 9.2347e-01, 	grad norm: 2.4084e-02 	Update/norm: 7.0076e-04
# final.bias,   	norm: 1.8018e-01, 	grad norm: 1.4166e-04 	Update/norm: 2.1124e-05
#
# Iter 40... ... ...
# Iter 50... ..
# Iteration 60, loss = 0.2387
# Validation loss 0.2394 over 81 frames
# conv_a1.weight,   	norm: 4.5213e+00, 	grad norm: 1.3753e-02 	Update/norm: 7.7354e-05
# conv_a1.bias,   	norm: 3.0213e-01, 	grad norm: 5.1976e-05 	Update/norm: 4.3747e-06
# conv_b1.weight,   	norm: 4.2073e+00, 	grad norm: 1.9478e-02 	Update/norm: 1.1772e-04
# conv_b1.bias,   	norm: 2.2065e-01, 	grad norm: 3.5214e-05 	Update/norm: 4.0583e-06
# final.weight,   	norm: 8.8367e-01, 	grad norm: 3.1102e-02 	Update/norm: 8.9503e-04
# final.bias,   	norm: 1.8158e-01, 	grad norm: 1.3790e-04 	Update/norm: 1.9312e-05
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iteration 80, loss = 0.2165
# Validation loss 0.2385 over 81 frames
# conv_a1.weight,   	norm: 4.5280e+00, 	grad norm: 1.5929e-02 	Update/norm: 8.4665e-05
# conv_a1.bias,   	norm: 3.0243e-01, 	grad norm: 4.5812e-05 	Update/norm: 3.6455e-06
# conv_b1.weight,   	norm: 4.2054e+00, 	grad norm: 1.8837e-02 	Update/norm: 1.0780e-04
# conv_b1.bias,   	norm: 2.2075e-01, 	grad norm: 3.7377e-05 	Update/norm: 4.0749e-06
# final.weight,   	norm: 8.7572e-01, 	grad norm: 2.6316e-02 	Update/norm: 7.2322e-04
# final.bias,   	norm: 1.8297e-01, 	grad norm: 1.3100e-04 	Update/norm: 1.7231e-05
#
# Iter 80
# Epoch 1 Iteration 0, loss = 0.2165
# Validation loss 0.2369 over 81 frames
# conv_a1.weight,   	norm: 4.5280e+00, 	grad norm: 6.6099e-02 	Update/norm: 3.5035e-04
# conv_a1.bias,   	norm: 3.0245e-01, 	grad norm: 3.1138e-05 	Update/norm: 2.4708e-06
# conv_b1.weight,   	norm: 4.2054e+00, 	grad norm: 8.7196e-02 	Update/norm: 4.9762e-04
# conv_b1.bias,   	norm: 2.2075e-01, 	grad norm: 1.9997e-05 	Update/norm: 2.1740e-06
# final.weight,   	norm: 8.7469e-01, 	grad norm: 1.5280e-01 	Update/norm: 4.1925e-03
# final.bias,   	norm: 1.8304e-01, 	grad norm: 8.0914e-05 	Update/norm: 1.0609e-05
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iteration 20, loss = 0.2232
# Validation loss 0.2385 over 81 frames
# conv_a1.weight,   	norm: 4.5292e+00, 	grad norm: 4.1316e-02 	Update/norm: 2.0720e-04
# conv_a1.bias,   	norm: 3.0272e-01, 	grad norm: 5.3380e-05 	Update/norm: 4.0052e-06
# conv_b1.weight,   	norm: 4.2053e+00, 	grad norm: 5.4590e-02 	Update/norm: 2.9485e-04
# conv_b1.bias,   	norm: 2.2089e-01, 	grad norm: 4.6991e-05 	Update/norm: 4.8320e-06
# final.weight,   	norm: 8.7121e-01, 	grad norm: 9.5290e-02 	Update/norm: 2.4843e-03
# final.bias,   	norm: 1.8435e-01, 	grad norm: 1.5890e-04 	Update/norm: 1.9578e-05
#
# Iter 20... ... ...
# Iter 30... ... ...
# Iteration 40, loss = 0.2386
# Validation loss 0.2394 over 81 frames
# conv_a1.weight,   	norm: 4.5297e+00, 	grad norm: 2.2382e-02 	Update/norm: 1.0622e-04
# conv_a1.bias,   	norm: 3.0296e-01, 	grad norm: 4.9976e-05 	Update/norm: 3.5459e-06
# conv_b1.weight,   	norm: 4.2060e+00, 	grad norm: 3.1730e-02 	Update/norm: 1.6217e-04
# conv_b1.bias,   	norm: 2.2105e-01, 	grad norm: 3.7752e-05 	Update/norm: 3.6711e-06
# final.weight,   	norm: 8.7533e-01, 	grad norm: 5.7481e-02 	Update/norm: 1.4116e-03
# final.bias,   	norm: 1.8560e-01, 	grad norm: 1.3294e-04 	Update/norm: 1.5397e-05
#
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.2194
# Validation loss 0.2364 over 81 frames
# conv_a1.weight,   	norm: 4.5293e+00, 	grad norm: 3.0396e-02 	Update/norm: 1.3652e-04
# conv_a1.bias,   	norm: 3.0318e-01, 	grad norm: 4.2041e-05 	Update/norm: 2.8210e-06
# conv_b1.weight,   	norm: 4.2067e+00, 	grad norm: 4.0234e-02 	Update/norm: 1.9457e-04
# conv_b1.bias,   	norm: 2.2123e-01, 	grad norm: 4.6036e-05 	Update/norm: 4.2334e-06
# final.weight,   	norm: 8.7621e-01, 	grad norm: 7.3864e-02 	Update/norm: 1.7149e-03
# final.bias,   	norm: 1.8677e-01, 	grad norm: 1.3980e-04 	Update/norm: 1.5227e-05
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iteration 80, loss = 0.2155
# Validation loss 0.2373 over 81 frames
# conv_a1.weight,   	norm: 4.5290e+00, 	grad norm: 8.0390e-03 	Update/norm: 3.4174e-05
# conv_a1.bias,   	norm: 3.0339e-01, 	grad norm: 3.9728e-05 	Update/norm: 2.5212e-06
# conv_b1.weight,   	norm: 4.2073e+00, 	grad norm: 1.1407e-02 	Update/norm: 5.2201e-05
# conv_b1.bias,   	norm: 2.2141e-01, 	grad norm: 3.6965e-05 	Update/norm: 3.2143e-06
# final.weight,   	norm: 8.7843e-01, 	grad norm: 2.1761e-02 	Update/norm: 4.7695e-04
# final.bias,   	norm: 1.8789e-01, 	grad norm: 1.1639e-04 	Update/norm: 1.1927e-05
#
# Iter 80
# Epoch 2 Iteration 0, loss = 0.2397
# Validation loss 0.2380 over 81 frames
# conv_a1.weight,   	norm: 4.5290e+00, 	grad norm: 7.6190e-03 	Update/norm: 3.2300e-05
# conv_a1.bias,   	norm: 3.0340e-01, 	grad norm: 5.2317e-05 	Update/norm: 3.3108e-06
# conv_b1.weight,   	norm: 4.2074e+00, 	grad norm: 1.1096e-02 	Update/norm: 5.0636e-05
# conv_b1.bias,   	norm: 2.2142e-01, 	grad norm: 4.4989e-05 	Update/norm: 3.9011e-06
# final.weight,   	norm: 8.7824e-01, 	grad norm: 1.9738e-02 	Update/norm: 4.3151e-04
# final.bias,   	norm: 1.8794e-01, 	grad norm: 1.4411e-04 	Update/norm: 1.4723e-05
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iteration 20, loss = 0.2382
# Validation loss 0.2352 over 81 frames
# conv_a1.weight,   	norm: 4.5285e+00, 	grad norm: 3.0210e-02 	Update/norm: 1.2122e-04
# conv_a1.bias,   	norm: 3.0359e-01, 	grad norm: 5.2260e-05 	Update/norm: 3.1279e-06
# conv_b1.weight,   	norm: 4.2080e+00, 	grad norm: 4.2621e-02 	Update/norm: 1.8404e-04
# conv_b1.bias,   	norm: 2.2161e-01, 	grad norm: 5.1088e-05 	Update/norm: 4.1890e-06
# final.weight,   	norm: 8.7964e-01, 	grad norm: 7.5704e-02 	Update/norm: 1.5638e-03
# final.bias,   	norm: 1.8900e-01, 	grad norm: 1.5689e-04 	Update/norm: 1.5084e-05
#
# Iter 20... ... ...
# Iter 30... ... ...
# Iteration 40, loss = 0.2431
# Validation loss 0.2386 over 81 frames
# conv_a1.weight,   	norm: 4.5278e+00, 	grad norm: 1.0989e-02 	Update/norm: 4.1736e-05
# conv_a1.bias,   	norm: 3.0377e-01, 	grad norm: 4.7414e-05 	Update/norm: 2.6841e-06
# conv_b1.weight,   	norm: 4.2086e+00, 	grad norm: 1.5512e-02 	Update/norm: 6.3382e-05
# conv_b1.bias,   	norm: 2.2179e-01, 	grad norm: 4.8654e-05 	Update/norm: 3.7724e-06
# final.weight,   	norm: 8.7966e-01, 	grad norm: 2.7072e-02 	Update/norm: 5.2924e-04
# final.bias,   	norm: 1.8998e-01, 	grad norm: 1.4688e-04 	Update/norm: 1.3295e-05
#
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.2548
# Validation loss 0.2361 over 81 frames
# conv_a1.weight,   	norm: 4.5271e+00, 	grad norm: 2.0870e-03 	Update/norm: 7.5029e-06
# conv_a1.bias,   	norm: 3.0394e-01, 	grad norm: 5.2080e-05 	Update/norm: 2.7887e-06
# conv_b1.weight,   	norm: 4.2091e+00, 	grad norm: 2.1495e-03 	Update/norm: 8.3113e-06
# conv_b1.bias,   	norm: 2.2197e-01, 	grad norm: 5.0590e-05 	Update/norm: 3.7093e-06
# final.weight,   	norm: 8.7854e-01, 	grad norm: 2.2514e-03 	Update/norm: 4.1708e-05
# final.bias,   	norm: 1.9091e-01, 	grad norm: 1.5102e-04 	Update/norm: 1.2874e-05
# Iter 60... ... ...
# Iter 70... ... ...
# Iteration 80, loss = 0.2232
# Validation loss 0.2380 over 81 frames
# conv_a1.weight,   	norm: 4.5267e+00, 	grad norm: 2.0067e-03 	Update/norm: 6.8280e-06
# conv_a1.bias,   	norm: 3.0409e-01, 	grad norm: 4.2680e-05 	Update/norm: 2.1618e-06
# conv_b1.weight,   	norm: 4.2098e+00, 	grad norm: 2.0903e-03 	Update/norm: 7.6476e-06
# conv_b1.bias,   	norm: 2.2214e-01, 	grad norm: 4.4046e-05 	Update/norm: 3.0539e-06
# final.weight,   	norm: 8.8034e-01, 	grad norm: 3.3588e-03 	Update/norm: 5.8765e-05
# final.bias,   	norm: 1.9180e-01, 	grad norm: 1.3017e-04 	Update/norm: 1.0453e-05
#
# Iter 80

# %%
# One last test + visualize results on 1 validation sequence
val_seq = TAVR_Sequence("__valid")
test(model, val_loader, loss_fn, device)
test(ave_model, val_loader, loss_fn, device)

with torch.no_grad():
    model.eval()
    ave_frames = [val_seq[0][0]]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:], val_seq[0][i][None,:]))
        ave_frames += [ave_frame[0][0],  val_seq[0][i]]
    ave_frames += [val_seq[0][9]]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# Validation loss 0.2363 over 81 frames
# Validation loss 0.0048 over 81 frames
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
from utils.loss_functions import batch_mse_loss
mse_loss_fn = batch_mse_loss()

from time import time
t = []
t.append(time())
test(model, val_loader, mse_loss_fn, device)
t.append(time())
test(ave_model, val_loader, mse_loss_fn, device)
t.append(time())
test(model, val_loader, loss_fn, device)
t.append(time())
test(ave_model, val_loader, loss_fn, device)
t.append(time())

for i in range(1, len(t)):
    print(t[i]-t[i-1])
# Out:
# Validation loss 4033946.0000 over 81 frames
# Validation loss 1468.3656 over 81 frames
# Validation loss 0.2381 over 81 frames
# Validation loss 0.0047 over 81 frames
# 105.04296255111694
# 14.075073480606079
# 107.34071278572083
# 13.867462873458862
