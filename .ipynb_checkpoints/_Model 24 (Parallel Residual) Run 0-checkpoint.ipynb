# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test, save, load, get_loss_history
from Models.basic_models import average_model, two_layer_basic, post_process
from Models.nm_layer import nm_layer_net, Parallel_Residual

set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)

# "Pixl", "Slice", or "None"
preproc_type = "pixel"

validation = TAVR_3_Frame("__valid", preproc=preproc_type, preload=False)
val_loader = tavr_dataloader(validation, batch_size=2, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train", preproc=preproc_type, preload=False)
train_loader = tavr_dataloader(training,batch_size=2, shuffle=True, num_workers=2)


ave_model = average_model()
model = Parallel_Residual(2, [4,8],[4,1])
post_proc = post_process(kind=preproc_type).to(device=device)
loss_fn = batch_l2_loss()

# CHANGE TO NAME OF JUPYTER NOTEBOOK
model_name = "Model 24 (Parallel Residual) Run 0"
# Out:
# using device: cuda

# %%
learning_rate = 1e-3
reg = 0

optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

# %%
LOAD = False
iteration_num = -1

if LOAD:
    load(model_name, iteration_num, model, optimizer)
    loss_history = get_loss_history(model_name)
    model.to(device=device)
    # I don't know why these lines are necessary
    # or even what the hell they do
    # but they are
    if str(device) == 'cuda':
        for state in optimizer.state.values():
            for k, v in state.items():
                state[k] = v.cuda()
else:
    loss_history = None

# %%
# If multiple GPU
# model = nn.DataParallel(model)

# %%
train(model, post_proc, optimizer, train_loader, val_loader, loss_fn, device, 
         model_name, loss_history,
          epochs=2, print_every=60, print_level=4, lr_decay=1)
# Out:
# Iteration 0, loss = 4.0991, corrected loss = 1907.4362
# Validation loss 1692.9102 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-0
# para_0.conv_a1.weight,   	norm: 2.7698e+00, 	update norm: 1.0392e-02 	Update/norm: 3.7520e-03
# para_0.conv_a1.bias,   	norm: 2.5752e-01, 	update norm: 2.0000e-03 	Update/norm: 7.7664e-03
# para_0.conv_b1.weight,   	norm: 2.8197e+00, 	update norm: 1.0392e-02 	Update/norm: 3.6856e-03
# para_0.conv_b1.bias,   	norm: 1.2648e-01, 	update norm: 2.0000e-03 	Update/norm: 1.5812e-02
# para_0.conv_a2.weight,   	norm: 4.1438e+00, 	update norm: 2.9373e-02 	Update/norm: 7.0883e-03
# para_0.conv_a2.bias,   	norm: 1.3389e-01, 	update norm: 2.8280e-03 	Update/norm: 2.1121e-02
# para_0.conv_b2.weight,   	norm: 3.9735e+00, 	update norm: 2.9384e-02 	Update/norm: 7.3950e-03
# para_0.conv_b2.bias,   	norm: 1.6449e-01, 	update norm: 2.8284e-03 	Update/norm: 1.7195e-02
# para_0.conv_ab1.weight,   	norm: 2.8175e+00, 	update norm: 4.1551e-02 	Update/norm: 1.4748e-02
# para_0.conv_ab1.bias,   	norm: 5.2507e-02, 	update norm: 2.0000e-03 	Update/norm: 3.8089e-02
# para_0.conv_ab2.weight,   	norm: 1.4360e+00, 	update norm: 1.0392e-02 	Update/norm: 7.2367e-03
# para_0.conv_ab2.bias,   	norm: 1.1596e-02, 	update norm: 1.0000e-03 	Update/norm: 8.6235e-02
# para_1.conv_a1.weight,   	norm: 2.8703e+00, 	update norm: 1.0391e-02 	Update/norm: 3.6203e-03
# para_1.conv_a1.bias,   	norm: 2.5863e-01, 	update norm: 2.0000e-03 	Update/norm: 7.7331e-03
# para_1.conv_b1.weight,   	norm: 2.7843e+00, 	update norm: 1.0391e-02 	Update/norm: 3.7320e-03
# para_1.conv_b1.bias,   	norm: 1.9742e-01, 	update norm: 2.0000e-03 	Update/norm: 1.0130e-02
# para_1.conv_a2.weight,   	norm: 4.0147e+00, 	update norm: 2.9358e-02 	Update/norm: 7.3126e-03
# para_1.conv_a2.bias,   	norm: 1.4933e-01, 	update norm: 2.8283e-03 	Update/norm: 1.8940e-02
# para_1.conv_b2.weight,   	norm: 4.0892e+00, 	update norm: 2.9384e-02 	Update/norm: 7.1857e-03
# para_1.conv_b2.bias,   	norm: 1.9178e-01, 	update norm: 2.8284e-03 	Update/norm: 1.4748e-02
# para_1.conv_ab1.weight,   	norm: 2.8662e+00, 	update norm: 4.1561e-02 	Update/norm: 1.4501e-02
# para_1.conv_ab1.bias,   	norm: 5.6224e-02, 	update norm: 2.0000e-03 	Update/norm: 3.5572e-02
# para_1.conv_ab2.weight,   	norm: 1.5628e+00, 	update norm: 1.0392e-02 	Update/norm: 6.6496e-03
# para_1.conv_ab2.bias,   	norm: 1.4095e-02, 	update norm: 1.0000e-03 	Update/norm: 7.0947e-02
#
# ... 1.2525... 0.2027... 0.1093
# Iter 10... 0.1200... 0.1001... 0.0843
# Iter 20... 0.0761... 0.0560... 0.0710
# Iter 30... 0.0731... 0.0738... 0.0602
# Iter 40... 0.0926... 0.1073... 0.1195
# Iter 50... 0.0925... 0.0780... 0.0752
# Iteration 60, loss = 0.1076, corrected loss = 50.0843
# Validation loss 38.4249 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-60
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 4.2879e-05 	Update/norm: 1.5518e-05
# para_0.conv_a1.bias,   	norm: 2.5882e-01, 	update norm: 8.0732e-06 	Update/norm: 3.1193e-05
# para_0.conv_b1.weight,   	norm: 2.8224e+00, 	update norm: 3.8310e-05 	Update/norm: 1.3574e-05
# para_0.conv_b1.bias,   	norm: 1.0432e-01, 	update norm: 7.4290e-06 	Update/norm: 7.1216e-05
# para_0.conv_a2.weight,   	norm: 4.1283e+00, 	update norm: 1.6453e-04 	Update/norm: 3.9855e-05
# para_0.conv_a2.bias,   	norm: 1.4835e-01, 	update norm: 9.8242e-06 	Update/norm: 6.6223e-05
# para_0.conv_b2.weight,   	norm: 3.9962e+00, 	update norm: 1.2092e-04 	Update/norm: 3.0259e-05
# para_0.conv_b2.bias,   	norm: 1.8857e-01, 	update norm: 1.2326e-05 	Update/norm: 6.5367e-05
# para_0.conv_ab1.weight,   	norm: 2.8991e+00, 	update norm: 2.6566e-04 	Update/norm: 9.1635e-05
# para_0.conv_ab1.bias,   	norm: 6.7441e-02, 	update norm: 1.1585e-05 	Update/norm: 1.7179e-04
# para_0.conv_ab2.weight,   	norm: 1.4152e+00, 	update norm: 4.5241e-05 	Update/norm: 3.1969e-05
# para_0.conv_ab2.bias,   	norm: 6.8956e-03, 	update norm: 7.4985e-06 	Update/norm: 1.0874e-03
# para_1.conv_a1.weight,   	norm: 2.8444e+00, 	update norm: 5.0336e-04 	Update/norm: 1.7697e-04
# para_1.conv_a1.bias,   	norm: 2.3935e-01, 	update norm: 6.7657e-05 	Update/norm: 2.8266e-04
# para_1.conv_b1.weight,   	norm: 2.7608e+00, 	update norm: 4.3208e-04 	Update/norm: 1.5651e-04
# para_1.conv_b1.bias,   	norm: 1.9548e-01, 	update norm: 3.3879e-05 	Update/norm: 1.7331e-04
# para_1.conv_a2.weight,   	norm: 4.0394e+00, 	update norm: 2.7948e-03 	Update/norm: 6.9189e-04
# para_1.conv_a2.bias,   	norm: 1.7413e-01, 	update norm: 1.8462e-04 	Update/norm: 1.0602e-03
# para_1.conv_b2.weight,   	norm: 4.0901e+00, 	update norm: 2.1796e-03 	Update/norm: 5.3290e-04
# para_1.conv_b2.bias,   	norm: 1.9790e-01, 	update norm: 1.0812e-04 	Update/norm: 5.4633e-04
# para_1.conv_ab1.weight,   	norm: 2.8932e+00, 	update norm: 2.2480e-03 	Update/norm: 7.7700e-04
# para_1.conv_ab1.bias,   	norm: 6.8509e-02, 	update norm: 1.3119e-05 	Update/norm: 1.9149e-04
# para_1.conv_ab2.weight,   	norm: 1.5553e+00, 	update norm: 2.4423e-04 	Update/norm: 1.5703e-04
# para_1.conv_ab2.bias,   	norm: 1.1725e-02, 	update norm: 1.6454e-04 	Update/norm: 1.4034e-02
#
# ... 0.0633... 0.0638... 0.0583
# Iter 70... 0.0798... 0.0816... 0.0654
# Iter 80... 0.0721... 0.0868... 0.0725
# Iter 90... 0.0872... 0.0558... 0.1248
# Iter 100... 0.0748... 0.0831... 0.0531
# Iter 110... 0.0604... 0.0515... 0.0896
# Iteration 120, loss = 0.0731, corrected loss = 34.0108
# Validation loss 38.0008 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-120
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 1.9506e-07 	Update/norm: 7.0589e-08
# para_0.conv_a1.bias,   	norm: 2.5882e-01, 	update norm: 2.6863e-08 	Update/norm: 1.0379e-07
# para_0.conv_b1.weight,   	norm: 2.8225e+00, 	update norm: 2.2621e-07 	Update/norm: 8.0145e-08
# para_0.conv_b1.bias,   	norm: 1.0425e-01, 	update norm: 5.6497e-08 	Update/norm: 5.4192e-07
# para_0.conv_a2.weight,   	norm: 4.1281e+00, 	update norm: 4.7081e-05 	Update/norm: 1.1405e-05
# para_0.conv_a2.bias,   	norm: 1.4832e-01, 	update norm: 1.9873e-06 	Update/norm: 1.3399e-05
# para_0.conv_b2.weight,   	norm: 3.9963e+00, 	update norm: 1.2701e-05 	Update/norm: 3.1781e-06
# para_0.conv_b2.bias,   	norm: 1.8867e-01, 	update norm: 1.4715e-07 	Update/norm: 7.7992e-07
# para_0.conv_ab1.weight,   	norm: 2.8998e+00, 	update norm: 4.1703e-05 	Update/norm: 1.4382e-05
# para_0.conv_ab1.bias,   	norm: 6.7517e-02, 	update norm: 4.2295e-08 	Update/norm: 6.2644e-07
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 1.5843e-07 	Update/norm: 1.1196e-07
# para_0.conv_ab2.bias,   	norm: 6.9793e-03, 	update norm: 3.8184e-08 	Update/norm: 5.4710e-06
# para_1.conv_a1.weight,   	norm: 2.8409e+00, 	update norm: 2.6563e-04 	Update/norm: 9.3502e-05
# para_1.conv_a1.bias,   	norm: 2.3878e-01, 	update norm: 3.7149e-05 	Update/norm: 1.5557e-04
# para_1.conv_b1.weight,   	norm: 2.7572e+00, 	update norm: 2.1603e-04 	Update/norm: 7.8353e-05
# para_1.conv_b1.bias,   	norm: 1.9543e-01, 	update norm: 3.8495e-05 	Update/norm: 1.9697e-04
# para_1.conv_a2.weight,   	norm: 4.0392e+00, 	update norm: 1.1425e-03 	Update/norm: 2.8284e-04
# para_1.conv_a2.bias,   	norm: 1.7673e-01, 	update norm: 4.4065e-05 	Update/norm: 2.4933e-04
# para_1.conv_b2.weight,   	norm: 4.0880e+00, 	update norm: 1.0120e-03 	Update/norm: 2.4755e-04
# para_1.conv_b2.bias,   	norm: 1.9927e-01, 	update norm: 3.2584e-05 	Update/norm: 1.6351e-04
# para_1.conv_ab1.weight,   	norm: 2.8850e+00, 	update norm: 1.0565e-03 	Update/norm: 3.6621e-04
# para_1.conv_ab1.bias,   	norm: 6.8484e-02, 	update norm: 9.3251e-06 	Update/norm: 1.3617e-04
# para_1.conv_ab2.weight,   	norm: 1.5547e+00, 	update norm: 1.2226e-04 	Update/norm: 7.8643e-05
# para_1.conv_ab2.bias,   	norm: 2.0103e-02, 	update norm: 1.2602e-04 	Update/norm: 6.2689e-03
#
# ... 0.0766... 0.0744... 0.0573
# Iter 130... 0.0592... 0.0634... 0.0984
# Iter 140... 0.0753... 0.0848... 0.0892
# Iter 150... 0.0586... 0.0489... 0.0609
# Iter 160... 0.0767... 0.0780... 0.0793
# Iter 170... 0.0957... 0.0634... 0.0604
# Iteration 180, loss = 0.0704, corrected loss = 32.7812
# Validation loss 37.6844 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-180
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 7.8689e-07 	Update/norm: 2.8477e-07
# para_0.conv_a1.bias,   	norm: 2.5882e-01, 	update norm: 1.4901e-08 	Update/norm: 5.7574e-08
# para_0.conv_b1.weight,   	norm: 2.8225e+00, 	update norm: 1.6761e-07 	Update/norm: 5.9386e-08
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 6.0097e-08 	Update/norm: 5.7644e-07
# para_0.conv_a2.weight,   	norm: 4.1274e+00, 	update norm: 1.2374e-04 	Update/norm: 2.9979e-05
# para_0.conv_a2.bias,   	norm: 1.4820e-01, 	update norm: 2.6460e-06 	Update/norm: 1.7854e-05
# para_0.conv_b2.weight,   	norm: 3.9962e+00, 	update norm: 9.5520e-06 	Update/norm: 2.3902e-06
# para_0.conv_b2.bias,   	norm: 1.8868e-01, 	update norm: 2.2055e-07 	Update/norm: 1.1689e-06
# para_0.conv_ab1.weight,   	norm: 2.8998e+00, 	update norm: 1.4599e-04 	Update/norm: 5.0345e-05
# para_0.conv_ab1.bias,   	norm: 6.7520e-02, 	update norm: 1.4898e-07 	Update/norm: 2.2064e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 1.8979e-07 	Update/norm: 1.3412e-07
# para_0.conv_ab2.bias,   	norm: 6.9866e-03, 	update norm: 6.7055e-08 	Update/norm: 9.5977e-06
# para_1.conv_a1.weight,   	norm: 2.8399e+00, 	update norm: 2.0010e-04 	Update/norm: 7.0460e-05
# para_1.conv_a1.bias,   	norm: 2.3484e-01, 	update norm: 5.8568e-05 	Update/norm: 2.4939e-04
# para_1.conv_b1.weight,   	norm: 2.7574e+00, 	update norm: 1.1937e-04 	Update/norm: 4.3289e-05
# para_1.conv_b1.bias,   	norm: 1.9278e-01, 	update norm: 4.7563e-05 	Update/norm: 2.4673e-04
# para_1.conv_a2.weight,   	norm: 4.0402e+00, 	update norm: 4.5916e-04 	Update/norm: 1.1365e-04
# para_1.conv_a2.bias,   	norm: 1.7803e-01, 	update norm: 1.4365e-05 	Update/norm: 8.0685e-05
# para_1.conv_b2.weight,   	norm: 4.0879e+00, 	update norm: 9.3547e-04 	Update/norm: 2.2884e-04
# para_1.conv_b2.bias,   	norm: 2.0013e-01, 	update norm: 6.3646e-05 	Update/norm: 3.1801e-04
# para_1.conv_ab1.weight,   	norm: 2.8827e+00, 	update norm: 1.2940e-03 	Update/norm: 4.4888e-04
# para_1.conv_ab1.bias,   	norm: 6.6486e-02, 	update norm: 3.2250e-05 	Update/norm: 4.8507e-04
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 1.8625e-05 	Update/norm: 1.1983e-05
# para_1.conv_ab2.bias,   	norm: 2.6518e-02, 	update norm: 2.7433e-05 	Update/norm: 1.0345e-03
# ... 0.0944... 0.0895... 0.0901
# Iter 190... 0.1040... 0.0753... 0.0920
# Iter 200... 0.0597... 0.0586... 0.0711
# Iter 210... 0.1165... 0.0512... 0.0975
# Iter 220... 0.0789... 0.0677... 0.0677
# Iter 230... 0.0829... 0.0677... 0.0674
# Iteration 240, loss = 0.0750, corrected loss = 34.8999
# Validation loss 37.6449 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-240
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 3.6395e-07 	Update/norm: 1.3171e-07
# para_0.conv_a1.bias,   	norm: 2.5881e-01, 	update norm: 1.2428e-07 	Update/norm: 4.8020e-07
# para_0.conv_b1.weight,   	norm: 2.8225e+00, 	update norm: 1.3229e-07 	Update/norm: 4.6870e-08
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 8.5783e-08 	Update/norm: 8.2281e-07
# para_0.conv_a2.weight,   	norm: 4.1271e+00, 	update norm: 1.6459e-04 	Update/norm: 3.9880e-05
# para_0.conv_a2.bias,   	norm: 1.4813e-01, 	update norm: 4.0796e-06 	Update/norm: 2.7541e-05
# para_0.conv_b2.weight,   	norm: 3.9962e+00, 	update norm: 9.6755e-06 	Update/norm: 2.4212e-06
# para_0.conv_b2.bias,   	norm: 1.8869e-01, 	update norm: 2.7437e-07 	Update/norm: 1.4541e-06
# para_0.conv_ab1.weight,   	norm: 2.8998e+00, 	update norm: 5.3821e-05 	Update/norm: 1.8560e-05
# para_0.conv_ab1.bias,   	norm: 6.7523e-02, 	update norm: 2.4712e-07 	Update/norm: 3.6598e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 4.3301e-07 	Update/norm: 3.0599e-07
# para_0.conv_ab2.bias,   	norm: 6.9913e-03, 	update norm: 8.4285e-08 	Update/norm: 1.2056e-05
# para_1.conv_a1.weight,   	norm: 2.8398e+00, 	update norm: 5.0635e-05 	Update/norm: 1.7831e-05
# para_1.conv_a1.bias,   	norm: 2.3377e-01, 	update norm: 1.4923e-05 	Update/norm: 6.3835e-05
# para_1.conv_b1.weight,   	norm: 2.7578e+00, 	update norm: 5.3690e-05 	Update/norm: 1.9468e-05
# para_1.conv_b1.bias,   	norm: 1.9172e-01, 	update norm: 2.1500e-05 	Update/norm: 1.1214e-04
# para_1.conv_a2.weight,   	norm: 4.0405e+00, 	update norm: 8.3526e-05 	Update/norm: 2.0672e-05
# para_1.conv_a2.bias,   	norm: 1.7834e-01, 	update norm: 3.9250e-06 	Update/norm: 2.2008e-05
# para_1.conv_b2.weight,   	norm: 4.0881e+00, 	update norm: 2.6973e-04 	Update/norm: 6.5980e-05
# para_1.conv_b2.bias,   	norm: 2.0058e-01, 	update norm: 2.2259e-05 	Update/norm: 1.1097e-04
# para_1.conv_ab1.weight,   	norm: 2.8831e+00, 	update norm: 3.1243e-04 	Update/norm: 1.0836e-04
# para_1.conv_ab1.bias,   	norm: 6.5739e-02, 	update norm: 8.5050e-06 	Update/norm: 1.2938e-04
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 1.8601e-06 	Update/norm: 1.1968e-06
# para_1.conv_ab2.bias,   	norm: 2.7081e-02, 	update norm: 3.5837e-06 	Update/norm: 1.3233e-04
#
# ... 0.0456... 0.0951... 0.0657
# Iter 250... 0.0551... 0.0728... 0.0633
# Iter 260... 0.0657... 0.0793... 0.0647
# Iter 270... 0.0814... 0.0599... 0.0771
# Iter 280... 0.0663... 0.0788... 0.0767
# Iter 290... 0.0698... 0.0658... 0.0872
# Iteration 300, loss = 0.0770, corrected loss = 35.8248
# Validation loss 37.6088 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-300
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 1.7420e-07 	Update/norm: 6.3040e-08
# para_0.conv_a1.bias,   	norm: 2.5881e-01, 	update norm: 4.5320e-08 	Update/norm: 1.7511e-07
# para_0.conv_b1.weight,   	norm: 2.8225e+00, 	update norm: 1.5842e-07 	Update/norm: 5.6130e-08
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 3.4597e-08 	Update/norm: 3.3185e-07
# para_0.conv_a2.weight,   	norm: 4.1270e+00, 	update norm: 3.4603e-05 	Update/norm: 8.3845e-06
# para_0.conv_a2.bias,   	norm: 1.4808e-01, 	update norm: 8.4298e-07 	Update/norm: 5.6925e-06
# para_0.conv_b2.weight,   	norm: 3.9962e+00, 	update norm: 9.5325e-06 	Update/norm: 2.3854e-06
# para_0.conv_b2.bias,   	norm: 1.8869e-01, 	update norm: 1.0517e-07 	Update/norm: 5.5737e-07
# para_0.conv_ab1.weight,   	norm: 2.8998e+00, 	update norm: 1.7817e-05 	Update/norm: 6.1440e-06
# para_0.conv_ab1.bias,   	norm: 6.7524e-02, 	update norm: 1.6683e-07 	Update/norm: 2.4707e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 1.1726e-07 	Update/norm: 8.2861e-08
# para_0.conv_ab2.bias,   	norm: 6.9931e-03, 	update norm: 5.1223e-09 	Update/norm: 7.3247e-07
# para_1.conv_a1.weight,   	norm: 2.8397e+00, 	update norm: 2.1982e-05 	Update/norm: 7.7409e-06
# para_1.conv_a1.bias,   	norm: 2.3330e-01, 	update norm: 8.6642e-06 	Update/norm: 3.7138e-05
# para_1.conv_b1.weight,   	norm: 2.7580e+00, 	update norm: 3.3890e-05 	Update/norm: 1.2288e-05
# para_1.conv_b1.bias,   	norm: 1.9100e-01, 	update norm: 1.6093e-05 	Update/norm: 8.4255e-05
# para_1.conv_a2.weight,   	norm: 4.0406e+00, 	update norm: 6.1208e-05 	Update/norm: 1.5148e-05
# para_1.conv_a2.bias,   	norm: 1.7847e-01, 	update norm: 2.3669e-06 	Update/norm: 1.3262e-05
# para_1.conv_b2.weight,   	norm: 4.0882e+00, 	update norm: 1.3724e-04 	Update/norm: 3.3569e-05
# para_1.conv_b2.bias,   	norm: 2.0081e-01, 	update norm: 1.2897e-05 	Update/norm: 6.4227e-05
# para_1.conv_ab1.weight,   	norm: 2.8832e+00, 	update norm: 1.4226e-04 	Update/norm: 4.9341e-05
# para_1.conv_ab1.bias,   	norm: 6.5471e-02, 	update norm: 4.3523e-06 	Update/norm: 6.6476e-05
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 9.1027e-07 	Update/norm: 5.8569e-07
# para_1.conv_ab2.bias,   	norm: 2.7227e-02, 	update norm: 2.0135e-06 	Update/norm: 7.3954e-05
#
# ... 0.0741... 0.0703... 0.0935
# Iter 310... 0.0798... 0.0588... 0.0752
# Iter 320..
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-323
# (Epoch time: 93.03 minutes. Total epochs: 1)
# . 0.0546... 0.1030... 0.0724
# Iter 330... 0.0905... 0.0947... 0.0701
# Iter 340... 0.0996... 0.1076... 0.0693
# Iter 350... 0.0699... 0.0798... 0.1113
# Iteration 360, loss = 0.0949, corrected loss = 44.1518
# Validation loss 37.6218 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-360
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 2.4679e-06 	Update/norm: 8.9310e-07
# para_0.conv_a1.bias,   	norm: 2.5881e-01, 	update norm: 9.8913e-08 	Update/norm: 3.8219e-07
# para_0.conv_b1.weight,   	norm: 2.8224e+00, 	update norm: 5.1779e-07 	Update/norm: 1.8346e-07
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 1.6023e-07 	Update/norm: 1.5369e-06
# para_0.conv_a2.weight,   	norm: 4.1263e+00, 	update norm: 4.5231e-04 	Update/norm: 1.0961e-04
# para_0.conv_a2.bias,   	norm: 1.4794e-01, 	update norm: 7.9737e-06 	Update/norm: 5.3897e-05
# para_0.conv_b2.weight,   	norm: 3.9961e+00, 	update norm: 3.4287e-05 	Update/norm: 8.5801e-06
# para_0.conv_b2.bias,   	norm: 1.8870e-01, 	update norm: 3.5232e-07 	Update/norm: 1.8671e-06
# para_0.conv_ab1.weight,   	norm: 2.8999e+00, 	update norm: 2.4092e-04 	Update/norm: 8.3077e-05
# para_0.conv_ab1.bias,   	norm: 6.7528e-02, 	update norm: 2.0578e-07 	Update/norm: 3.0473e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 2.0099e-07 	Update/norm: 1.4203e-07
# para_0.conv_ab2.bias,   	norm: 6.9991e-03, 	update norm: 1.7369e-07 	Update/norm: 2.4816e-05
# para_1.conv_a1.weight,   	norm: 2.8397e+00, 	update norm: 1.2492e-05 	Update/norm: 4.3991e-06
# para_1.conv_a1.bias,   	norm: 2.3298e-01, 	update norm: 5.8340e-06 	Update/norm: 2.5041e-05
# para_1.conv_b1.weight,   	norm: 2.7582e+00, 	update norm: 2.6194e-05 	Update/norm: 9.4966e-06
# para_1.conv_b1.bias,   	norm: 1.9041e-01, 	update norm: 1.1407e-05 	Update/norm: 5.9908e-05
# para_1.conv_a2.weight,   	norm: 4.0406e+00, 	update norm: 5.1592e-05 	Update/norm: 1.2769e-05
# para_1.conv_a2.bias,   	norm: 1.7856e-01, 	update norm: 2.1639e-06 	Update/norm: 1.2119e-05
# para_1.conv_b2.weight,   	norm: 4.0883e+00, 	update norm: 9.1619e-05 	Update/norm: 2.2410e-05
# para_1.conv_b2.bias,   	norm: 2.0095e-01, 	update norm: 8.9176e-06 	Update/norm: 4.4377e-05
# para_1.conv_ab1.weight,   	norm: 2.8833e+00, 	update norm: 1.0220e-04 	Update/norm: 3.5445e-05
# para_1.conv_ab1.bias,   	norm: 6.5307e-02, 	update norm: 2.8341e-06 	Update/norm: 4.3396e-05
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 5.6293e-07 	Update/norm: 3.6220e-07
# para_1.conv_ab2.bias,   	norm: 2.7324e-02, 	update norm: 1.3765e-06 	Update/norm: 5.0378e-05
#
# ... 0.0700... 0.0868... 0.0998
# Iter 370... 0.0539... 0.0956... 0.0641
# Iter 380... 0.0618... 0.0551... 0.1338
# Iter 390... 0.0603... 0.0960... 0.0871
# Iter 400... 0.0864... 0.0821... 0.0766
# Iter 410... 0.0392... 0.1036... 0.0686
# Iteration 420, loss = 0.1015, corrected loss = 47.2370
# Validation loss 37.6601 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-420
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 6.5801e-07 	Update/norm: 2.3813e-07
# para_0.conv_a1.bias,   	norm: 2.5880e-01, 	update norm: 4.7269e-08 	Update/norm: 1.8264e-07
# para_0.conv_b1.weight,   	norm: 2.8224e+00, 	update norm: 2.7109e-07 	Update/norm: 9.6049e-08
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 8.9871e-08 	Update/norm: 8.6200e-07
# para_0.conv_a2.weight,   	norm: 4.1259e+00, 	update norm: 2.4373e-04 	Update/norm: 5.9072e-05
# para_0.conv_a2.bias,   	norm: 1.4782e-01, 	update norm: 5.6817e-06 	Update/norm: 3.8437e-05
# para_0.conv_b2.weight,   	norm: 3.9960e+00, 	update norm: 1.6085e-05 	Update/norm: 4.0251e-06
# para_0.conv_b2.bias,   	norm: 1.8871e-01, 	update norm: 2.8693e-07 	Update/norm: 1.5205e-06
# para_0.conv_ab1.weight,   	norm: 2.9001e+00, 	update norm: 6.1531e-05 	Update/norm: 2.1217e-05
# para_0.conv_ab1.bias,   	norm: 6.7533e-02, 	update norm: 2.6121e-07 	Update/norm: 3.8679e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 2.3173e-07 	Update/norm: 1.6375e-07
# para_0.conv_ab2.bias,   	norm: 7.0054e-03, 	update norm: 8.4285e-08 	Update/norm: 1.2031e-05
# para_1.conv_a1.weight,   	norm: 2.8396e+00, 	update norm: 1.0076e-05 	Update/norm: 3.5483e-06
# para_1.conv_a1.bias,   	norm: 2.3271e-01, 	update norm: 5.1370e-06 	Update/norm: 2.2075e-05
# para_1.conv_b1.weight,   	norm: 2.7583e+00, 	update norm: 2.5704e-05 	Update/norm: 9.3188e-06
# para_1.conv_b1.bias,   	norm: 1.8988e-01, 	update norm: 1.1404e-05 	Update/norm: 6.0058e-05
# para_1.conv_a2.weight,   	norm: 4.0405e+00, 	update norm: 4.8424e-05 	Update/norm: 1.1985e-05
# para_1.conv_a2.bias,   	norm: 1.7863e-01, 	update norm: 1.6417e-06 	Update/norm: 9.1906e-06
# para_1.conv_b2.weight,   	norm: 4.0884e+00, 	update norm: 8.2947e-05 	Update/norm: 2.0289e-05
# para_1.conv_b2.bias,   	norm: 2.0105e-01, 	update norm: 7.9708e-06 	Update/norm: 3.9647e-05
# para_1.conv_ab1.weight,   	norm: 2.8833e+00, 	update norm: 8.6066e-05 	Update/norm: 2.9850e-05
# para_1.conv_ab1.bias,   	norm: 6.5185e-02, 	update norm: 2.5485e-06 	Update/norm: 3.9096e-05
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 5.2586e-07 	Update/norm: 3.3835e-07
# para_1.conv_ab2.bias,   	norm: 2.7401e-02, 	update norm: 1.2536e-06 	Update/norm: 4.5749e-05
#
# ... 0.0840... 0.0711... 0.0642
# Iter 430... 0.0871... 0.0670... 0.0646
# Iter 440... 0.0918... 0.0615... 0.0504
# Iter 450... 0.0698... 0.0659... 0.0821
# Iter 460... 0.0765... 0.1116... 0.0788
# Iter 470... 0.0892... 0.0476... 0.0531
# Iteration 480, loss = 0.0587, corrected loss = 27.3360
# Validation loss 37.7261 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-480
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 7.0447e-07 	Update/norm: 2.5494e-07
# para_0.conv_a1.bias,   	norm: 2.5880e-01, 	update norm: 1.1644e-07 	Update/norm: 4.4993e-07
# para_0.conv_b1.weight,   	norm: 2.8224e+00, 	update norm: 2.8274e-07 	Update/norm: 1.0018e-07
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 7.9376e-08 	Update/norm: 7.6133e-07
# para_0.conv_a2.weight,   	norm: 4.1255e+00, 	update norm: 1.9182e-04 	Update/norm: 4.6495e-05
# para_0.conv_a2.bias,   	norm: 1.4766e-01, 	update norm: 5.5279e-06 	Update/norm: 3.7436e-05
# para_0.conv_b2.weight,   	norm: 3.9960e+00, 	update norm: 2.5707e-05 	Update/norm: 6.4331e-06
# para_0.conv_b2.bias,   	norm: 1.8871e-01, 	update norm: 2.8596e-07 	Update/norm: 1.5153e-06
# para_0.conv_ab1.weight,   	norm: 2.9002e+00, 	update norm: 7.1057e-05 	Update/norm: 2.4501e-05
# para_0.conv_ab1.bias,   	norm: 6.7536e-02, 	update norm: 1.9442e-07 	Update/norm: 2.8787e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 1.4119e-07 	Update/norm: 9.9773e-08
# para_0.conv_ab2.bias,   	norm: 7.0101e-03, 	update norm: 1.2526e-07 	Update/norm: 1.7869e-05
# para_1.conv_a1.weight,   	norm: 2.8395e+00, 	update norm: 8.3537e-06 	Update/norm: 2.9420e-06
# para_1.conv_a1.bias,   	norm: 2.3252e-01, 	update norm: 2.9265e-06 	Update/norm: 1.2586e-05
# para_1.conv_b1.weight,   	norm: 2.7583e+00, 	update norm: 1.5071e-05 	Update/norm: 5.4639e-06
# para_1.conv_b1.bias,   	norm: 1.8942e-01, 	update norm: 7.3213e-06 	Update/norm: 3.8650e-05
# para_1.conv_a2.weight,   	norm: 4.0405e+00, 	update norm: 4.1682e-05 	Update/norm: 1.0316e-05
# para_1.conv_a2.bias,   	norm: 1.7869e-01, 	update norm: 1.6550e-06 	Update/norm: 9.2619e-06
# para_1.conv_b2.weight,   	norm: 4.0885e+00, 	update norm: 5.3001e-05 	Update/norm: 1.2964e-05
# para_1.conv_b2.bias,   	norm: 2.0112e-01, 	update norm: 5.6989e-06 	Update/norm: 2.8336e-05
# para_1.conv_ab1.weight,   	norm: 2.8834e+00, 	update norm: 6.5116e-05 	Update/norm: 2.2583e-05
# para_1.conv_ab1.bias,   	norm: 6.5086e-02, 	update norm: 1.8811e-06 	Update/norm: 2.8901e-05
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 3.3971e-07 	Update/norm: 2.1858e-07
# para_1.conv_ab2.bias,   	norm: 2.7471e-02, 	update norm: 9.1642e-07 	Update/norm: 3.3359e-05
#
# ... 0.0840... 0.0431... 0.0587
# Iter 490... 0.0563... 0.1158... 0.0643
# Iter 500... 0.1116... 0.0686... 0.0756
# Iter 510... 0.0774... 0.0693... 0.0672
# Iter 520... 0.0742... 0.0946... 0.0652
# Iter 530... 0.0758... 0.0688... 0.1095
# Iteration 540, loss = 0.0695, corrected loss = 32.3524
# Validation loss 37.7080 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-540
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 3.4387e-06 	Update/norm: 1.2444e-06
# para_0.conv_a1.bias,   	norm: 2.5880e-01, 	update norm: 1.9557e-07 	Update/norm: 7.5568e-07
# para_0.conv_b1.weight,   	norm: 2.8224e+00, 	update norm: 7.1826e-07 	Update/norm: 2.5448e-07
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 2.2504e-07 	Update/norm: 2.1585e-06
# para_0.conv_a2.weight,   	norm: 4.1247e+00, 	update norm: 1.1035e-03 	Update/norm: 2.6752e-04
# para_0.conv_a2.bias,   	norm: 1.4753e-01, 	update norm: 1.9716e-05 	Update/norm: 1.3364e-04
# para_0.conv_b2.weight,   	norm: 3.9960e+00, 	update norm: 4.4898e-05 	Update/norm: 1.1236e-05
# para_0.conv_b2.bias,   	norm: 1.8872e-01, 	update norm: 5.5781e-07 	Update/norm: 2.9558e-06
# para_0.conv_ab1.weight,   	norm: 2.9000e+00, 	update norm: 3.9785e-04 	Update/norm: 1.3719e-04
# para_0.conv_ab1.bias,   	norm: 6.7538e-02, 	update norm: 2.0962e-07 	Update/norm: 3.1038e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 3.0049e-07 	Update/norm: 2.1235e-07
# para_0.conv_ab2.bias,   	norm: 7.0160e-03, 	update norm: 3.4180e-07 	Update/norm: 4.8716e-05
# para_1.conv_a1.weight,   	norm: 2.8394e+00, 	update norm: 8.8807e-06 	Update/norm: 3.1277e-06
# para_1.conv_a1.bias,   	norm: 2.3237e-01, 	update norm: 4.5265e-06 	Update/norm: 1.9480e-05
# para_1.conv_b1.weight,   	norm: 2.7584e+00, 	update norm: 2.5559e-05 	Update/norm: 9.2660e-06
# para_1.conv_b1.bias,   	norm: 1.8908e-01, 	update norm: 1.0628e-05 	Update/norm: 5.6211e-05
# para_1.conv_a2.weight,   	norm: 4.0404e+00, 	update norm: 5.6545e-05 	Update/norm: 1.3995e-05
# para_1.conv_a2.bias,   	norm: 1.7875e-01, 	update norm: 1.3237e-06 	Update/norm: 7.4051e-06
# para_1.conv_b2.weight,   	norm: 4.0885e+00, 	update norm: 6.7531e-05 	Update/norm: 1.6517e-05
# para_1.conv_b2.bias,   	norm: 2.0116e-01, 	update norm: 6.5746e-06 	Update/norm: 3.2683e-05
# para_1.conv_ab1.weight,   	norm: 2.8834e+00, 	update norm: 8.4490e-05 	Update/norm: 2.9302e-05
# para_1.conv_ab1.bias,   	norm: 6.5010e-02, 	update norm: 1.8716e-06 	Update/norm: 2.8789e-05
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 2.9215e-07 	Update/norm: 1.8798e-07
# para_1.conv_ab2.bias,   	norm: 2.7527e-02, 	update norm: 9.5740e-07 	Update/norm: 3.4780e-05
#
# ... 0.0537... 0.0945... 0.0727
# Iter 550... 0.0773... 0.0932... 0.0559
# Iter 560... 0.0581... 0.0832... 0.0507
# Iter 570... 0.0482... 0.0909... 0.0909
# Iter 580... 0.0943... 0.0986... 0.0479
# Iter 590... 0.0887... 0.0569... 0.0673
# Iteration 600, loss = 0.0596, corrected loss = 27.7255
# Validation loss 37.7584 over 81 frames
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-600
# para_0.conv_a1.weight,   	norm: 2.7633e+00, 	update norm: 3.7830e-07 	Update/norm: 1.3690e-07
# para_0.conv_a1.bias,   	norm: 2.5879e-01, 	update norm: 3.5144e-08 	Update/norm: 1.3580e-07
# para_0.conv_b1.weight,   	norm: 2.8224e+00, 	update norm: 1.0667e-07 	Update/norm: 3.7795e-08
# para_0.conv_b1.bias,   	norm: 1.0426e-01, 	update norm: 2.1156e-08 	Update/norm: 2.0291e-07
# para_0.conv_a2.weight,   	norm: 4.1241e+00, 	update norm: 1.1240e-04 	Update/norm: 2.7255e-05
# para_0.conv_a2.bias,   	norm: 1.4740e-01, 	update norm: 1.8408e-06 	Update/norm: 1.2489e-05
# para_0.conv_b2.weight,   	norm: 3.9959e+00, 	update norm: 8.7436e-06 	Update/norm: 2.1881e-06
# para_0.conv_b2.bias,   	norm: 1.8873e-01, 	update norm: 5.3856e-08 	Update/norm: 2.8537e-07
# para_0.conv_ab1.weight,   	norm: 2.9000e+00, 	update norm: 3.8025e-05 	Update/norm: 1.3112e-05
# para_0.conv_ab1.bias,   	norm: 6.7542e-02, 	update norm: 1.3154e-07 	Update/norm: 1.9476e-06
# para_0.conv_ab2.weight,   	norm: 1.4151e+00, 	update norm: 1.5703e-07 	Update/norm: 1.1097e-07
# para_0.conv_ab2.bias,   	norm: 7.0225e-03, 	update norm: 2.0489e-08 	Update/norm: 2.9176e-06
# para_1.conv_a1.weight,   	norm: 2.8393e+00, 	update norm: 6.5067e-06 	Update/norm: 2.2917e-06
# para_1.conv_a1.bias,   	norm: 2.3221e-01, 	update norm: 4.8762e-06 	Update/norm: 2.1000e-05
# para_1.conv_b1.weight,   	norm: 2.7585e+00, 	update norm: 2.6837e-05 	Update/norm: 9.7290e-06
# para_1.conv_b1.bias,   	norm: 1.8867e-01, 	update norm: 1.1581e-05 	Update/norm: 6.1384e-05
# para_1.conv_a2.weight,   	norm: 4.0404e+00, 	update norm: 3.6884e-05 	Update/norm: 9.1289e-06
# para_1.conv_a2.bias,   	norm: 1.7880e-01, 	update norm: 1.5574e-06 	Update/norm: 8.7103e-06
# para_1.conv_b2.weight,   	norm: 4.0886e+00, 	update norm: 8.1996e-05 	Update/norm: 2.0055e-05
# para_1.conv_b2.bias,   	norm: 2.0122e-01, 	update norm: 6.7998e-06 	Update/norm: 3.3793e-05
# para_1.conv_ab1.weight,   	norm: 2.8834e+00, 	update norm: 6.3121e-05 	Update/norm: 2.1891e-05
# para_1.conv_ab1.bias,   	norm: 6.4932e-02, 	update norm: 2.0120e-06 	Update/norm: 3.0986e-05
# para_1.conv_ab2.weight,   	norm: 1.5542e+00, 	update norm: 3.3770e-07 	Update/norm: 2.1729e-07
# para_1.conv_ab2.bias,   	norm: 2.7581e-02, 	update norm: 9.7044e-07 	Update/norm: 3.5185e-05
#
# ... 0.0684... 0.0870... 0.0981
# Iter 610... 0.0492... 0.0590... 0.0732
# Iter 620... 0.0879... 0.0940... 0.1026
# Iter 630... 0.0655... 0.0781... 0.0801
# Iter 640... 0.0764..
# model saved to model_checkpoints/Model 24 (Parallel Residual) Run 0/Model 24 (Parallel Residual) Run 0-646

# %%
# One last test + visualize results on 1 validation sequence

test(model, post_proc, val_loader, loss_fn, device)
test(ave_model, post_proc, val_loader, loss_fn, device)
# Out:
# Validation loss 37.7567 over 81 frames
# Validation loss 37.6476 over 81 frames
# tensor(37.6476, device='cuda:0')

# %%
with torch.no_grad():
    model.eval()
    for t, (x1, y, x2, mask, max_z) in enumerate(val_loader):
        x1 = x1.to(device=device)  # move to device, e.g. GPU
        y = post_proc(y.to(device=device))
        x2 = x2.to(device=device)
        mask = mask.to(device=device)
        max_z = max_z.to(device=device)
        
        y_hat = post_proc(model((x1, x2)))
        L2_to_ground = loss_fn((y, y_hat, mask, max_z))
        L2_to_ave = loss_fn((post_proc(ave_model((x1,x2))), y_hat, mask, max_z))
        print("Batch %d. Prediction-Real dist: %.5f, Prediction-Ave dist:%.5f"%(t, L2_to_ground.item(), L2_to_ave.item()))
# Out:
# Batch 0. Prediction-Real dist: 45.84892, Prediction-Ave dist:0.22925
# Batch 1. Prediction-Real dist: 39.01183, Prediction-Ave dist:0.30086
# Batch 2. Prediction-Real dist: 39.69267, Prediction-Ave dist:0.16501
# Batch 3. Prediction-Real dist: 34.15722, Prediction-Ave dist:0.27250
# Batch 4. Prediction-Real dist: 35.24645, Prediction-Ave dist:0.28791
# Batch 5. Prediction-Real dist: 35.03659, Prediction-Ave dist:0.21807
# Batch 6. Prediction-Real dist: 37.61953, Prediction-Ave dist:0.21406
# Batch 7. Prediction-Real dist: 33.64201, Prediction-Ave dist:0.33550
# Batch 8. Prediction-Real dist: 47.19699, Prediction-Ave dist:0.25724
# Batch 9. Prediction-Real dist: 39.89621, Prediction-Ave dist:0.28795
# Batch 10. Prediction-Real dist: 42.96581, Prediction-Ave dist:0.22259
# Batch 11. Prediction-Real dist: 33.66465, Prediction-Ave dist:0.23733
# Batch 12. Prediction-Real dist: 35.71105, Prediction-Ave dist:0.28252
# Batch 13. Prediction-Real dist: 51.41776, Prediction-Ave dist:0.24455
# Batch 14. Prediction-Real dist: 30.18692, Prediction-Ave dist:0.32398
# Batch 15. Prediction-Real dist: 32.61797, Prediction-Ave dist:0.26306
# Batch 16. Prediction-Real dist: 38.96920, Prediction-Ave dist:0.18567
# Batch 17. Prediction-Real dist: 34.50686, Prediction-Ave dist:0.29564
# Batch 18. Prediction-Real dist: 44.70053, Prediction-Ave dist:0.19966
# Batch 19. Prediction-Real dist: 32.36043, Prediction-Ave dist:0.28680
# Batch 20. Prediction-Real dist: 33.82815, Prediction-Ave dist:0.31661
# Batch 21. Prediction-Real dist: 40.86638, Prediction-Ave dist:0.29190
# Batch 22. Prediction-Real dist: 38.52915, Prediction-Ave dist:0.23221
# Batch 23. Prediction-Real dist: 49.87928, Prediction-Ave dist:0.34232
# Batch 24. Prediction-Real dist: 37.28136, Prediction-Ave dist:0.17162
# Batch 25. Prediction-Real dist: 38.39815, Prediction-Ave dist:0.26143
# Batch 26. Prediction-Real dist: 34.30041, Prediction-Ave dist:0.30956
# Batch 27. Prediction-Real dist: 40.74925, Prediction-Ave dist:0.21359
# Batch 28. Prediction-Real dist: 42.92257, Prediction-Ave dist:0.27259
# Batch 29. Prediction-Real dist: 36.53723, Prediction-Ave dist:0.22570
# Batch 30. Prediction-Real dist: 42.39441, Prediction-Ave dist:0.30892
# Batch 31. Prediction-Real dist: 34.99366, Prediction-Ave dist:0.30927
# Batch 32. Prediction-Real dist: 42.81917, Prediction-Ave dist:0.22636
# Batch 33. Prediction-Real dist: 34.43208, Prediction-Ave dist:0.38688
# Batch 34. Prediction-Real dist: 40.47940, Prediction-Ave dist:0.24370
# Batch 35. Prediction-Real dist: 34.19645, Prediction-Ave dist:0.20493
# Batch 36. Prediction-Real dist: 39.49423, Prediction-Ave dist:0.16320
# Batch 37. Prediction-Real dist: 34.21501, Prediction-Ave dist:0.15986
# Batch 38. Prediction-Real dist: 34.14112, Prediction-Ave dist:0.30366
# Batch 39. Prediction-Real dist: 35.19510, Prediction-Ave dist:0.26759
# Batch 40. Prediction-Real dist: 34.10011, Prediction-Ave dist:0.14838

# %%
val_seq = TAVR_Sequence("__valid", preproc=preproc_type)
with torch.no_grad():
    model.eval()
    ave_frames = [post_proc(val_seq[0][0].to(device=device))]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:].to(device=device), val_seq[0][i][None,:].to(device=device)))
        ave_frames += [post_proc(ave_frame[0][0]),  post_proc(val_seq[0][i].to(device=device))]
    ave_frames += [post_proc(val_seq[0][9].to(device=device))]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
