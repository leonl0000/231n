# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test
from Models.basic_models import average_model, two_layer_basic

set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)


validation = TAVR_3_Frame("__valid")
val_loader = tavr_dataloader(validation, batch_size=16, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train")
train_loader = tavr_dataloader(training, batch_size=8, shuffle=True, num_workers=2)


ave_model = average_model()
model = two_layer_basic(standardize_slice=True)
loss_fn = batch_l2_loss()
# Out:
# using device: cpu

# %%
learning_rate = 3e-2
momentum = 0.95
reg = 1e-7

optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=reg, nesterov=True)

# %%
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3, lr_decay=0.8)
# Out:
# ****Epoch 0 Iteration 0, loss = 0.4917
# Validation loss 0.3850 over 81 frames
# conv_a1.weight,   	norm: 4.1179e+00, 	grad norm: 7.1311e-01 	Update/norm: 5.1953e-03
# conv_a1.bias,   	norm: 2.7647e-01, 	grad norm: 3.2318e-03 	Update/norm: 3.5069e-04
# conv_b1.weight,   	norm: 4.1853e+00, 	grad norm: 5.5177e-01 	Update/norm: 3.9551e-03
# conv_b1.bias,   	norm: 3.0062e-01, 	grad norm: 2.4748e-03 	Update/norm: 2.4696e-04
# final.weight,   	norm: 1.6382e+00, 	grad norm: 9.2974e-01 	Update/norm: 1.7026e-02
# final.bias,   	norm: 1.0701e-01, 	grad norm: 3.6762e-03 	Update/norm: 1.0306e-03
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iteration 20, loss = 0.1753
# Validation loss 0.1958 over 81 frames
# conv_a1.weight,   	norm: 4.0542e+00, 	grad norm: 2.5360e-02 	Update/norm: 1.7760e-04
# conv_a1.bias,   	norm: 2.7640e-01, 	grad norm: 1.2129e-04 	Update/norm: 1.2459e-05
# conv_b1.weight,   	norm: 4.1802e+00, 	grad norm: 2.6477e-02 	Update/norm: 1.7983e-04
# conv_b1.bias,   	norm: 3.0102e-01, 	grad norm: 1.6401e-04 	Update/norm: 1.5469e-05
# final.weight,   	norm: 1.4588e+00, 	grad norm: 3.8011e-02 	Update/norm: 7.3977e-04
# final.bias,   	norm: 1.0720e-01, 	grad norm: 3.3625e-04 	Update/norm: 8.9054e-05
#
# Iter 20... ... ...
# Iter 30... ... ...
# Iteration 40, loss = 0.1883
# Validation loss 0.1896 over 81 frames
# conv_a1.weight,   	norm: 4.0338e+00, 	grad norm: 2.6726e-02 	Update/norm: 1.7802e-04
# conv_a1.bias,   	norm: 2.7635e-01, 	grad norm: 2.5762e-04 	Update/norm: 2.5049e-05
# conv_b1.weight,   	norm: 4.1678e+00, 	grad norm: 2.1956e-02 	Update/norm: 1.4155e-04
# conv_b1.bias,   	norm: 3.0148e-01, 	grad norm: 1.9086e-04 	Update/norm: 1.7011e-05
# final.weight,   	norm: 1.3562e+00, 	grad norm: 3.1330e-02 	Update/norm: 6.2074e-04
# final.bias,   	norm: 1.0832e-01, 	grad norm: 3.1024e-04 	Update/norm: 7.6957e-05
#
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.1853
# Validation loss 0.1884 over 81 frames
# conv_a1.weight,   	norm: 4.0234e+00, 	grad norm: 1.7967e-02 	Update/norm: 1.1356e-04
# conv_a1.bias,   	norm: 2.7634e-01, 	grad norm: 2.5213e-04 	Update/norm: 2.3201e-05
# conv_b1.weight,   	norm: 4.1591e+00, 	grad norm: 1.5924e-02 	Update/norm: 9.7359e-05
# conv_b1.bias,   	norm: 3.0175e-01, 	grad norm: 1.9099e-04 	Update/norm: 1.6095e-05
# final.weight,   	norm: 1.2954e+00, 	grad norm: 2.2174e-02 	Update/norm: 4.3528e-04
# final.bias,   	norm: 1.0973e-01, 	grad norm: 4.1650e-04 	Update/norm: 9.6517e-05
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iteration 80, loss = 0.1741
# Validation loss 0.1866 over 81 frames
# conv_a1.weight,   	norm: 4.0171e+00, 	grad norm: 2.9707e-02 	Update/norm: 1.7797e-04
# conv_a1.bias,   	norm: 2.7639e-01, 	grad norm: 2.6363e-04 	Update/norm: 2.2954e-05
# conv_b1.weight,   	norm: 4.1528e+00, 	grad norm: 4.9352e-02 	Update/norm: 2.8600e-04
# conv_b1.bias,   	norm: 3.0194e-01, 	grad norm: 3.7696e-04 	Update/norm: 3.0046e-05
# final.weight,   	norm: 1.2555e+00, 	grad norm: 1.0512e-01 	Update/norm: 2.0149e-03
# final.bias,   	norm: 1.1099e-01, 	grad norm: 1.3245e-03 	Update/norm: 2.8720e-04
#
# Iter 80
# ****Epoch 1 Iteration 0, loss = 0.1771
# Validation loss 0.1863 over 81 frames
# conv_a1.weight,   	norm: 4.0169e+00, 	grad norm: 7.5552e-02 	Update/norm: 4.5140e-04
# conv_a1.bias,   	norm: 2.7640e-01, 	grad norm: 6.7438e-04 	Update/norm: 5.8557e-05
# conv_b1.weight,   	norm: 4.1525e+00, 	grad norm: 6.0028e-02 	Update/norm: 3.4694e-04
# conv_b1.bias,   	norm: 3.0195e-01, 	grad norm: 5.3787e-04 	Update/norm: 4.2752e-05
# final.weight,   	norm: 1.2539e+00, 	grad norm: 7.4470e-02 	Update/norm: 1.4253e-03
# final.bias,   	norm: 1.1104e-01, 	grad norm: 7.9478e-04 	Update/norm: 1.7178e-04
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iteration 20, loss = 0.1664
# Validation loss 0.1870 over 81 frames
# conv_a1.weight,   	norm: 4.0117e+00, 	grad norm: 1.2744e-02 	Update/norm: 7.2156e-05
# conv_a1.bias,   	norm: 2.7650e-01, 	grad norm: 2.0655e-04 	Update/norm: 1.6967e-05
# conv_b1.weight,   	norm: 4.1483e+00, 	grad norm: 9.6276e-03 	Update/norm: 5.2715e-05
# conv_b1.bias,   	norm: 3.0211e-01, 	grad norm: 1.7770e-04 	Update/norm: 1.3360e-05
# final.weight,   	norm: 1.2233e+00, 	grad norm: 1.4986e-02 	Update/norm: 2.7825e-04
# final.bias,   	norm: 1.1172e-01, 	grad norm: 1.7499e-04 	Update/norm: 3.5577e-05
#
# Iter 20... ... ...
# Iter 30... ... ...
# Iteration 40, loss = 0.1745
# Validation loss 0.1861 over 81 frames
# conv_a1.weight,   	norm: 4.0079e+00, 	grad norm: 3.1782e-02 	Update/norm: 1.7046e-04
# conv_a1.bias,   	norm: 2.7663e-01, 	grad norm: 3.3386e-04 	Update/norm: 2.5943e-05
# conv_b1.weight,   	norm: 4.1445e+00, 	grad norm: 2.7009e-02 	Update/norm: 1.4009e-04
# conv_b1.bias,   	norm: 3.0225e-01, 	grad norm: 2.6480e-04 	Update/norm: 1.8833e-05
# final.weight,   	norm: 1.1984e+00, 	grad norm: 3.9382e-02 	Update/norm: 7.0643e-04
# final.bias,   	norm: 1.1272e-01, 	grad norm: 4.7235e-04 	Update/norm: 9.0076e-05
#
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.1812
# Validation loss 0.1877 over 81 frames
# conv_a1.weight,   	norm: 4.0039e+00, 	grad norm: 3.1123e-02 	Update/norm: 1.5813e-04
# conv_a1.bias,   	norm: 2.7676e-01, 	grad norm: 3.5898e-04 	Update/norm: 2.6388e-05
# conv_b1.weight,   	norm: 4.1419e+00, 	grad norm: 3.4528e-02 	Update/norm: 1.6959e-04
# conv_b1.bias,   	norm: 3.0237e-01, 	grad norm: 2.9721e-04 	Update/norm: 1.9997e-05
# final.weight,   	norm: 1.1764e+00, 	grad norm: 7.2653e-02 	Update/norm: 1.2563e-03
# final.bias,   	norm: 1.1337e-01, 	grad norm: 1.1563e-03 	Update/norm: 2.0751e-04
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iteration 80, loss = 0.1645
# Validation loss 0.1867 over 81 frames
# conv_a1.weight,   	norm: 4.0007e+00, 	grad norm: 1.6772e-02 	Update/norm: 8.0716e-05
# conv_a1.bias,   	norm: 2.7690e-01, 	grad norm: 1.7325e-04 	Update/norm: 1.2046e-05
# conv_b1.weight,   	norm: 4.1395e+00, 	grad norm: 1.3763e-02 	Update/norm: 6.4012e-05
# conv_b1.bias,   	norm: 3.0249e-01, 	grad norm: 1.4063e-04 	Update/norm: 8.9513e-06
# final.weight,   	norm: 1.1576e+00, 	grad norm: 2.0717e-02 	Update/norm: 3.4456e-04
# final.bias,   	norm: 1.1417e-01, 	grad norm: 2.6957e-04 	Update/norm: 4.5459e-05
#
# Iter 80
# ****Epoch 2 Iteration 0, loss = 0.1810
# Validation loss 0.1875 over 81 frames
# conv_a1.weight,   	norm: 4.0005e+00, 	grad norm: 3.1539e-02 	Update/norm: 1.5137e-04
# conv_a1.bias,   	norm: 2.7691e-01, 	grad norm: 3.2345e-04 	Update/norm: 2.2427e-05
# conv_b1.weight,   	norm: 4.1394e+00, 	grad norm: 2.5507e-02 	Update/norm: 1.1831e-04
# conv_b1.bias,   	norm: 3.0249e-01, 	grad norm: 2.3892e-04 	Update/norm: 1.5165e-05
# final.weight,   	norm: 1.1567e+00, 	grad norm: 3.8831e-02 	Update/norm: 6.4457e-04
# final.bias,   	norm: 1.1423e-01, 	grad norm: 6.3661e-04 	Update/norm: 1.0701e-04
#
# Iter 0... ... ...
# Iter 10... ... .
# Iteration 20, loss = 0.1784
# ... ... ...
# Iter 30... ... ...
# Iteration 40, loss = 0.1788
# Validation loss 0.1868 over 81 frames
# conv_a1.weight,   	norm: 3.9952e+00, 	grad norm: 4.4858e-03 	Update/norm: 1.9309e-05
# conv_a1.bias,   	norm: 2.7716e-01, 	grad norm: 3.2086e-05 	Update/norm: 1.9908e-06
# conv_b1.weight,   	norm: 4.1356e+00, 	grad norm: 4.6688e-03 	Update/norm: 1.9414e-05
# conv_b1.bias,   	norm: 3.0270e-01, 	grad norm: 3.3296e-05 	Update/norm: 1.8915e-06
# final.weight,   	norm: 1.1248e+00, 	grad norm: 1.3418e-02 	Update/norm: 2.0514e-04
# final.bias,   	norm: 1.1565e-01, 	grad norm: 3.7680e-05 	Update/norm: 5.6029e-06
#
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 0.1747
# Validation loss 0.1858 over 81 frames
# conv_a1.weight,   	norm: 3.9929e+00, 	grad norm: 1.9134e-03 	Update/norm: 7.7988e-06
# conv_a1.bias,   	norm: 2.7727e-01, 	grad norm: 4.8070e-05 	Update/norm: 2.8215e-06
# conv_b1.weight,   	norm: 4.1340e+00, 	grad norm: 1.9664e-03 	Update/norm: 7.7411e-06
# conv_b1.bias,   	norm: 3.0278e-01, 	grad norm: 4.7545e-05 	Update/norm: 2.5556e-06
# final.weight,   	norm: 1.1113e+00, 	grad norm: 5.8208e-03 	Update/norm: 8.5246e-05
# final.bias,   	norm: 1.1639e-01, 	grad norm: 4.8116e-05 	Update/norm: 6.7278e-06
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iteration 80, loss = 0.1772
# Validation loss 0.1871 over 81 frames
# conv_a1.weight,   	norm: 3.9906e+00, 	grad norm: 2.3780e-02 	Update/norm: 9.1784e-05
# conv_a1.bias,   	norm: 2.7736e-01, 	grad norm: 1.7878e-04 	Update/norm: 9.9279e-06
# conv_b1.weight,   	norm: 4.1328e+00, 	grad norm: 2.6272e-02 	Update/norm: 9.7915e-05
# conv_b1.bias,   	norm: 3.0288e-01, 	grad norm: 1.5665e-04 	Update/norm: 7.9660e-06
# final.weight,   	norm: 1.0986e+00, 	grad norm: 6.6465e-02 	Update/norm: 9.3180e-04
# final.bias,   	norm: 1.1675e-01, 	grad norm: 6.4583e-04 	Update/norm: 8.5203e-05
#
# Iter 80

# %%
# One last test + visualize results on 1 validation sequence
val_seq = TAVR_Sequence("__valid")
test(model, val_loader, loss_fn, device)
test(ave_model, val_loader, loss_fn, device)

with torch.no_grad():
    model.eval()
    ave_frames = [val_seq[0][0]]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:], val_seq[0][i][None,:]))
        ave_frames += [ave_frame[0][0],  val_seq[0][i]]
    ave_frames += [val_seq[0][9]]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# Validation loss 0.1870 over 81 frames
# Validation loss 0.0048 over 81 frames
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
optimizer.param_groups[0]['lr']
# Out:
# 0.015402372967960548

# %%
for p in model.parameters():
    print(p.norm())
# Out:
# tensor(3.9906)
# tensor(0.2774)
# tensor(4.1328)
# tensor(0.3029)
# tensor(1.0986)
# tensor(0.1167)
