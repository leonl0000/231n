# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
training = TAVR_1_Frame('__train')

# %% [markdown]
# ## Finding the Mean slice

# %%
mean_and_zcount = [(frame.mean(dim=0), frame.shape[0]) for frame in training]
zcounts = [z for (mean, z) in mean_and_zcount]

# %%
mean_slice = torch.zeros(256,256)
total_z = sum(zcounts)
for mean, z in mean_and_zcount:
    mean_slice += z * mean / total_z

# %%
display_grid(1,1,[mean_slice])

# %% [markdown]
# ## Finding the variance slice

# %%
var_slice = torch.zeros(256,256)
for frame in training:
    var_slice = ((frame - mean_slice)**2).sum(dim=0) / total_z

# %%
print("Max var: %f\nMin var: %f"%(var_slice.max(), var_slice.min()))
display_grid(1,1,[var_slice])
# Out:
# Max var: 1720.696533
# Min var: 5.930026

# %%
mew_slice = var_slice.sqrt()
print("Max std dev: %f\nMin std dev: %f"%(mew_slice.max(), mew_slice.min()))
display_grid(1,1,[mew_slice])
# Out:
# Max std dev: 41.481277
# Min std dev: 2.435164

# %% [markdown]
# ## Visualizing some standardized frames

# %%
set_figsize(12,9)
visualize_frame((training[0]-mean_slice)/mew_slice)
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
visualize_frame((training[700]-mean_slice)/mew_slice)
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
ind = 42
print("STD mean: \t%f \nSTD std: \t%f \nPre mean: \t%f \nPre std: \t%f"%
      (((training[ind]-mean_slice)/mew_slice).mean(),
       ((training[ind]-mean_slice)/mew_slice).std(),
       training[ind].mean(),
       training[ind].std()
      ))
# Out:
# STD mean: 	1.063515
# STD std: 	28.948133
# Pre mean: 	836.725342
# Pre std: 	433.954346

# %%
# Timing
for frame in training:
    stdized = (frame - mean_slice)/mew_slice

# %% [markdown]
# ## Save the mean and mew slice

# %%
np.save("data_numpy/mean_slice.npy", mean_slice)
np.save("data_numpy/mew_slice.npy", mew_slice)
