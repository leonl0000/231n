# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test, save, load, get_loss_history
from Models.basic_models import average_model, two_layer_basic, post_process, two_d_basic

set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = False
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)

# "Pixl", "Slice", or "None"
preproc_type = "pixel"

validation = TAVR_3_Frame("__valid", preproc=preproc_type)
val_loader = tavr_dataloader(validation, batch_size=4, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train", preproc=preproc_type)
train_loader = tavr_dataloader(training,batch_size=8, shuffle=True, num_workers=2)


ave_model = average_model()
model = two_d_basic()
post_proc = post_process(kind=preproc_type).to(device=device)
loss_fn = batch_l2_loss()

# CHANGE TO NAME OF JUPYTER NOTEBOOK
model_name = "Model 6 (2d CNN+PixelNorm) Run 0"
# Out:
# using device: cpu

# %%
learning_rate = 3e-3
momentum = 0.90
reg = 1e-7

optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=reg, nesterov=True)

# %%
# Run cell to load model
LOAD = True
iteration_num = 81

if LOAD:
    
    load(model_name, iteration_num, model, optimizer)
    loss_history = get_loss_history(model_name)
    model.to(device=device)
else:
    loss_history = None
# Out:
# model loaded from model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-81

# %%
train(model, post_proc, optimizer, train_loader, val_loader, loss_fn, device, 
         model_name, loss_history, epochs=3, print_every=30, print_level=4, lr_decay=1)
# Out:
# ... 0.1501... 0.1482... 0.1469
# Iteration 90, loss = 0.1594, corrected loss = 74.1699
# Validation loss 67.7046 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-90
# conv_a1.weight,   	norm: 3.3733e+00, 	update norm: 1.3006e-03 	Update/norm: 3.8557e-04
# conv_a1.bias,   	norm: 5.4011e-01, 	update norm: 2.4066e-04 	Update/norm: 4.4557e-04
# conv_b1.weight,   	norm: 3.9783e+00, 	update norm: 1.8358e-03 	Update/norm: 4.6144e-04
# conv_b1.bias,   	norm: 4.2492e-01, 	update norm: 2.9697e-04 	Update/norm: 6.9889e-04
# final.weight,   	norm: 1.0359e+00, 	update norm: 3.5668e-03 	Update/norm: 3.4433e-03
# final.bias,   	norm: 1.0853e-02, 	update norm: 2.1946e-05 	Update/norm: 2.0221e-03
#
# ... 0.1514... 0.1443... 0.1402
# Iter 100... 0.1501... 0.1280... 0.1363
# Iter 110... 0.1445... 0.1393... 0.1244
# Iteration 120, loss = 0.1416, corrected loss = 65.8892
# Validation loss 62.1541 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-120
# conv_a1.weight,   	norm: 3.3695e+00, 	update norm: 1.0852e-03 	Update/norm: 3.2206e-04
# conv_a1.bias,   	norm: 5.3671e-01, 	update norm: 2.3798e-04 	Update/norm: 4.4341e-04
# conv_b1.weight,   	norm: 3.9690e+00, 	update norm: 1.4969e-03 	Update/norm: 3.7715e-04
# conv_b1.bias,   	norm: 4.2845e-01, 	update norm: 5.1764e-04 	Update/norm: 1.2082e-03
# final.weight,   	norm: 9.8811e-01, 	update norm: 2.7978e-03 	Update/norm: 2.8314e-03
# final.bias,   	norm: 1.5200e-02, 	update norm: 1.0631e-04 	Update/norm: 6.9941e-03
#
# ... 0.1294... 0.1294... 0.1293
# Iter 130... 0.1252... 0.1338... 0.1386
# Iter 140... 0.1447... 0.1269... 0.1243
# Iteration 150, loss = 0.1438, corrected loss = 66.9080
# Validation loss 58.0915 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-150
# conv_a1.weight,   	norm: 3.3673e+00, 	update norm: 9.1832e-04 	Update/norm: 2.7272e-04
# conv_a1.bias,   	norm: 5.3414e-01, 	update norm: 2.1716e-04 	Update/norm: 4.0655e-04
# conv_b1.weight,   	norm: 3.9616e+00, 	update norm: 1.2834e-03 	Update/norm: 3.2395e-04
# conv_b1.bias,   	norm: 4.3248e-01, 	update norm: 4.9514e-04 	Update/norm: 1.1449e-03
# final.weight,   	norm: 9.5161e-01, 	update norm: 2.3435e-03 	Update/norm: 2.4627e-03
# final.bias,   	norm: 1.7711e-02, 	update norm: 4.3798e-05 	Update/norm: 2.4729e-03
#
# ... 0.1291... 0.1229... 0.1209
# Iter 160.
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-162
# (Epoch time: 29.20 minutes. Total epochs: 1)
# .. 0.1208... 0.1365... 0.1240
# Iter 170... 0.1231... 0.1247... 0.1259
# Iteration 180, loss = 0.1257, corrected loss = 58.5090
# Validation loss 55.0894 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-180
# conv_a1.weight,   	norm: 3.3659e+00, 	update norm: 8.0446e-04 	Update/norm: 2.3900e-04
# conv_a1.bias,   	norm: 5.3208e-01, 	update norm: 2.0204e-04 	Update/norm: 3.7972e-04
# conv_b1.weight,   	norm: 3.9560e+00, 	update norm: 1.1318e-03 	Update/norm: 2.8609e-04
# conv_b1.bias,   	norm: 4.3645e-01, 	update norm: 4.6296e-04 	Update/norm: 1.0607e-03
# final.weight,   	norm: 9.2409e-01, 	update norm: 2.0441e-03 	Update/norm: 2.2121e-03
# final.bias,   	norm: 2.0524e-02, 	update norm: 5.2866e-05 	Update/norm: 2.5758e-03
#
# ... 0.1147... 0.1228... 0.1143
# Iter 190... 0.1210... 0.1115... 0.1218
# Iter 200... 0.1192... 0.1064... 0.1265
# Iteration 210, loss = 0.1275, corrected loss = 59.3102
# Validation loss 52.8344 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-210
# conv_a1.weight,   	norm: 3.3648e+00, 	update norm: 7.0541e-04 	Update/norm: 2.0964e-04
# conv_a1.bias,   	norm: 5.3024e-01, 	update norm: 1.5755e-04 	Update/norm: 2.9712e-04
# conv_b1.weight,   	norm: 3.9517e+00, 	update norm: 1.0051e-03 	Update/norm: 2.5434e-04
# conv_b1.bias,   	norm: 4.4022e-01, 	update norm: 3.9161e-04 	Update/norm: 8.8956e-04
# final.weight,   	norm: 9.0270e-01, 	update norm: 1.7161e-03 	Update/norm: 1.9011e-03
# final.bias,   	norm: 2.3484e-02, 	update norm: 3.6785e-05 	Update/norm: 1.5664e-03
#
# ... 0.1214... 0.1055... 0.1133
# Iter 220... 0.1147... 0.1041... 0.1210
# Iter 230... 0.1076... 0.1058... 0.1158
# Iteration 240, loss = 0.1310, corrected loss = 60.9756
# Validation loss 51.0913 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-240
# conv_a1.weight,   	norm: 3.3640e+00, 	update norm: 6.6113e-04 	Update/norm: 1.9653e-04
# conv_a1.bias,   	norm: 5.2882e-01, 	update norm: 1.3758e-04 	Update/norm: 2.6017e-04
# conv_b1.weight,   	norm: 3.9483e+00, 	update norm: 9.5244e-04 	Update/norm: 2.4123e-04
# conv_b1.bias,   	norm: 4.4396e-01, 	update norm: 4.1597e-04 	Update/norm: 9.3697e-04
# final.weight,   	norm: 8.8611e-01, 	update norm: 1.4451e-03 	Update/norm: 1.6308e-03
# final.bias,   	norm: 2.5225e-02, 	update norm: 1.4578e-04 	Update/norm: 5.7792e-03
#
# ..
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-243
# (Epoch time: 39.04 minutes. Total epochs: 2)
# . 0.1209... 0.1066... 0.1030
# Iter 250... 0.0975... 0.1071... 0.1122
# Iter 260... 0.1065... 0.1188... 0.1176
# Iteration 270, loss = 0.0955, corrected loss = 44.4483
# Validation loss 49.7068 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-270
# conv_a1.weight,   	norm: 3.3635e+00, 	update norm: 6.2296e-04 	Update/norm: 1.8521e-04
# conv_a1.bias,   	norm: 5.2757e-01, 	update norm: 1.3777e-04 	Update/norm: 2.6115e-04
# conv_b1.weight,   	norm: 3.9457e+00, 	update norm: 8.5104e-04 	Update/norm: 2.1569e-04
# conv_b1.bias,   	norm: 4.4751e-01, 	update norm: 3.4536e-04 	Update/norm: 7.7174e-04
# final.weight,   	norm: 8.7333e-01, 	update norm: 1.3127e-03 	Update/norm: 1.5031e-03
# final.bias,   	norm: 2.7239e-02, 	update norm: 3.5366e-05 	Update/norm: 1.2984e-03
#
# ... 0.1053... 0.1178... 0.1171
# Iter 280... 0.1005... 0.1035... 0.1145
# Iter 290... 0.1016... 0.1130... 0.1069
# Iteration 300, loss = 0.1075, corrected loss = 50.0179
# Validation loss 48.7180 over 81 frames
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-300
# conv_a1.weight,   	norm: 3.3630e+00, 	update norm: 5.9930e-04 	Update/norm: 1.7820e-04
# conv_a1.bias,   	norm: 5.2659e-01, 	update norm: 1.1205e-04 	Update/norm: 2.1278e-04
# conv_b1.weight,   	norm: 3.9435e+00, 	update norm: 7.8210e-04 	Update/norm: 1.9833e-04
# conv_b1.bias,   	norm: 4.5080e-01, 	update norm: 3.0265e-04 	Update/norm: 6.7136e-04
# final.weight,   	norm: 8.6282e-01, 	update norm: 1.1312e-03 	Update/norm: 1.3111e-03
# final.bias,   	norm: 2.9074e-02, 	update norm: 5.7705e-06 	Update/norm: 1.9848e-04
#
# ... 0.1158... 0.1006... 0.1104
# Iter 310... 0.1103... 0.1072... 0.0964
# Iter 320... 0.0997
# model saved to model_checkpoints/Model 6 (2d CNN+PixelNorm) Run 0/Model 6 (2d CNN+PixelNorm) Run 0-324

# %%
# One last test + visualize results on 1 validation sequence
# One last test + visualize results on 1 validation sequence
val_seq = TAVR_Sequence("__valid")
test(ave_model, post_proc, val_loader, loss_fn, device)
test(model, post_proc, val_loader, loss_fn, device)

with torch.no_grad():
    model.eval()
    ave_frames = [post_proc(val_seq[0][0])]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:], val_seq[0][i][None,:]))
        print(ave_frame.shape)
        ave_frames += [post_proc(ave_frame[0]),  post_proc(val_seq[0][i])]
    ave_frames += [post_proc(val_seq[0][9])]
    ave_frames_slices = []
    for f in ave_frames:
        print(f.shape)
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# Validation loss 36.9453 over 81 frames
# Validation loss 47.9623 over 81 frames
# torch.Size([1, 77, 256, 256])
# torch.Size([1, 77, 256, 256])
# torch.Size([1, 77, 256, 256])
# torch.Size([1, 77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# torch.Size([77, 256, 256])
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
optimizer.param_groups[0]['lr']
# Out:
# 0.003

# %%
for p in model.parameters():
    print(p.norm())
# Out:
# tensor(3.3626)
# tensor(0.5260)
# tensor(3.9422)
# tensor(0.4535)
# tensor(0.8565)
# tensor(1.00000e-02 *
#        2.9982)
