# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

from utils.gif_loss import plot_loss

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test, save, load, get_loss_history
from Models.basic_models import average_model, two_layer_basic, post_process



set_figsize(20, 15)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def retrieve_losses(histories, loss_name='train_c'):
    return [np.array(history[loss_name]) for history in histories]

def get_final_loss(histories, loss_name='valid'):
    return [history[loss_name][-1] for history in histories]

# %%
import os
models = os.listdir("model_checkpoints")

# %%
models.pop(10)
# Out:
# 'Model 4 (Basic+PixelNorm) Run 2 [Adam]'

# %%
nice_names = ["M_7 (two_layer_resnet)",
"M_25 (Wide Parallel Residual)",
"M_5 (Basic)",
"M_6 (1,1 layer 2D PixelNorm)",
"M_10 (3,1 layer 2D)",
"M_5.1 (Basic+PixelNorm)",
"M_6 (2d CNN+PixelNorm)",
"M_23 (2,2 layer, Residual)",
"M_21 (1,1 layer ResNet)",
"M_22 (2,2 layer+PixNorm)",
"M_8 (Basic SliceNorm)",
"M_9 (2,1 layer 2d)",
"M_20 (1,1 layer+SliceNorm)",
"M_22 (2,2 layer+PixelNorm)",
"M_4.1 (Basic+PixelNorm)",
"M_24 (Parallel Residual)"]

# %%
models.pop(10)
# Out:
# 'Model 22 (2,2 layer+PixNorm) Run 1 [No L2 reg]'

# %%
model_hists = [get_loss_history(model) for model in models]

# %%
losses = retrieve_losses(model_hists, "valid")

# %%
plot_loss(losses + [35.150 * np.ones(11)], models + ["AVE"], marker=False, x_axis="(30) Iterations")

# %%
final_valid = get_final_loss(model_hists, "valid")

# %%
val_mod = []
for i, mod in enumerate(models):
    val_mod += [(final_valid[i], mod, nice_names[i])]
    print(mod, '\t', final_valid[i])
# Out:
# Model 7 (two_layer_resnet) Run 0 	 45.33277893066406
# Model 25 (Wide Parallel Residual) Run 0 	 37.74538803100586
# Model 5 (Basic+PixelNorm) 	 364.6773681640625
# Model 6 (2d CNN+PixelNorm) Run 0 	 48.718040466308594
# Model 10 (three layer - 2d) Run 0 	 44.02072525024414
# Model 5 (Basic+PixelNorm) R1 	 49.49930953979492
# Model 6 (2d CNN+PixelNorm-Adam) Run 1 	 66.922607421875
# Model 23 (2,2 layer, Residual+PixNorm) Run 0 	 36.773948669433594
# Model 21 (2_layer_res+SliceNorm+high L2 Reg) Run 0 [V100] 	 43.475826263427734
# Model 22 (2,2 layer+PixNorm) Run 1 [No L2 reg] 	 112.92716217041016
# Model 8 (Basic+SliceNorm) Run 0 	 356.6943054199219
# Model 9 (two layer - 2d) run 0 	 53.69823455810547
# Model 20 (2_layer_res+SliceNorm) Run 0 [V100] 	 44.44083786010742
# Model 22 (2,2 layer+PixNorm) Run 0 	 47.93421936035156
# Model 4 (Basic+PixelNorm) Run 1 	 47.08378601074219
# Model 24 (Parallel Residual) Run 0 	 358.09716796875

# %%
sorted(val_mod)
# Out:
# [(36.773948669433594,
#   'Model 23 (2,2 layer, Residual+PixNorm) Run 0',
#   'M_23 (2,2 layer, Residual)'),
#  (37.74538803100586,
#   'Model 25 (Wide Parallel Residual) Run 0',
#   'M_25 (Wide Parallel Residual)'),
#  (43.475826263427734,
#   'Model 21 (2_layer_res+SliceNorm+high L2 Reg) Run 0 [V100]',
#   'M_21 (1,1 layer ResNet)'),
#  (44.02072525024414,
#   'Model 10 (three layer - 2d) Run 0',
#   'M_10 (3,1 layer 2D)'),
#  (44.44083786010742,
#   'Model 20 (2_layer_res+SliceNorm) Run 0 [V100]',
#   'M_20 (1,1 layer+SliceNorm)'),
#  (45.33277893066406,
#   'Model 7 (two_layer_resnet) Run 0',
#   'M_7 (two_layer_resnet)'),
#  (47.08378601074219,
#   'Model 4 (Basic+PixelNorm) Run 1',
#   'M_4.1 (Basic+PixelNorm)'),
#  (47.93421936035156,
#   'Model 22 (2,2 layer+PixNorm) Run 0',
#   'M_22 (2,2 layer+PixelNorm)'),
#  (48.718040466308594,
#   'Model 6 (2d CNN+PixelNorm) Run 0',
#   'M_6 (1,1 layer 2D PixelNorm)'),
#  (49.49930953979492,
#   'Model 5 (Basic+PixelNorm) R1',
# ...

# %%
to_graph = sorted(val_mod)[:12]

# %%
names = [x[1] for x in to_graph]
nnames = [x[2] for x in to_graph]
model_hists = [get_loss_history(model) for model in names]
losses = retrieve_losses(model_hists, "valid")

# %%
u_loss = retrieve_losses(model_hists, "train")
plot_loss(u_loss[0:4], nnames[0:4], marker=False, y_axis="uncorrected loss", x_axis="Iterations")

# %%
plot_loss([losses[0], 35.150 * np.ones(11)], [nnames[0], "AVE"], marker=False, x_axis="(30) Iterations")

# %%
plot_loss(losses + [35.150 * np.ones(11)], nnames + ["AVE"], marker=False, x_axis="(30) Iterations")
