# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test, save, load, get_loss_history
from Models.basic_models import average_model, two_layer_basic, post_process
from Models.nm_layer import nm_layer_net

set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)

# "Pixl", "Slice", or "None"
preproc_type = "pixel"

validation = TAVR_3_Frame("__valid", preproc=preproc_type, preload=False)
val_loader = tavr_dataloader(validation, batch_size=4, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train", preproc=preproc_type, preload=False)
train_loader = tavr_dataloader(training,batch_size=4, shuffle=True, num_workers=2)


ave_model = average_model()
model = nm_layer_net([4,8],[4,1], True)
post_proc = post_process(kind=preproc_type).to(device=device)
loss_fn = batch_l2_loss()

# CHANGE TO NAME OF JUPYTER NOTEBOOK
model_name = "Model 23 (2,2 layer, Residual+PixNorm) Run 0"
# Out:
# using device: cuda

# %%
learning_rate = 1e-3
reg = 0

optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

# %%
LOAD = False
iteration_num = -1

if LOAD:
    load(model_name, iteration_num, model, optimizer)
    loss_history = get_loss_history(model_name)
    model.to(device=device)
    # I don't know why these lines are necessary
    # or even what the hell they do
    # but they are
    if str(device) == 'cuda':
        for state in optimizer.state.values():
            for k, v in state.items():
                state[k] = v.cuda()
else:
    loss_history = None

# %%
# If multiple GPU
# model = nn.DataParallel(model)

# %%
train(model, post_proc, optimizer, train_loader, val_loader, loss_fn, device, 
         model_name, loss_history,
          epochs=2, print_every=30, print_level=4, lr_decay=1)
# Out:
# Iteration 0, loss = 0.4906, corrected loss = 228.2934
# Validation loss 160.7200 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-0
# conv_a1.weight,   	norm: 3.0538e+00, 	update norm: 1.0392e-02 	Update/norm: 3.4031e-03
# conv_a1.bias,   	norm: 1.6896e-01, 	update norm: 2.0000e-03 	Update/norm: 1.1837e-02
# conv_b1.weight,   	norm: 2.9542e+00, 	update norm: 1.0391e-02 	Update/norm: 3.5175e-03
# conv_b1.bias,   	norm: 2.1039e-01, 	update norm: 2.0000e-03 	Update/norm: 9.5057e-03
# conv_a2.weight,   	norm: 3.9032e+00, 	update norm: 2.9375e-02 	Update/norm: 7.5258e-03
# conv_a2.bias,   	norm: 1.6831e-01, 	update norm: 2.8283e-03 	Update/norm: 1.6804e-02
# conv_b2.weight,   	norm: 3.8770e+00, 	update norm: 2.9381e-02 	Update/norm: 7.5781e-03
# conv_b2.bias,   	norm: 1.1453e-01, 	update norm: 2.8283e-03 	Update/norm: 2.4695e-02
# conv_ab1.weight,   	norm: 2.8970e+00, 	update norm: 4.1564e-02 	Update/norm: 1.4348e-02
# conv_ab1.bias,   	norm: 7.7725e-02, 	update norm: 2.0000e-03 	Update/norm: 2.5732e-02
# conv_ab2.weight,   	norm: 1.1896e+00, 	update norm: 1.0392e-02 	Update/norm: 8.7362e-03
# conv_ab2.bias,   	norm: 2.8964e-02, 	update norm: 1.0000e-03 	Update/norm: 3.4526e-02
#
# ... 0.1064... 0.0724... 0.0788
# Iter 10... 0.0680... 0.0619... 0.0697
# Iter 20... 0.0909... 0.0613... 0.0726
# Iteration 30, loss = 0.0792, corrected loss = 36.8729
# Validation loss 36.8883 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-30
# conv_a1.weight,   	norm: 3.0364e+00, 	update norm: 4.4830e-04 	Update/norm: 1.4764e-04
# conv_a1.bias,   	norm: 1.6310e-01, 	update norm: 9.1168e-05 	Update/norm: 5.5897e-04
# conv_b1.weight,   	norm: 2.9451e+00, 	update norm: 4.9824e-04 	Update/norm: 1.6918e-04
# conv_b1.bias,   	norm: 2.1146e-01, 	update norm: 7.6581e-05 	Update/norm: 3.6216e-04
# conv_a2.weight,   	norm: 3.8918e+00, 	update norm: 1.4719e-03 	Update/norm: 3.7821e-04
# conv_a2.bias,   	norm: 1.8794e-01, 	update norm: 1.4287e-04 	Update/norm: 7.6019e-04
# conv_b2.weight,   	norm: 3.8787e+00, 	update norm: 1.4808e-03 	Update/norm: 3.8179e-04
# conv_b2.bias,   	norm: 1.2244e-01, 	update norm: 1.4725e-04 	Update/norm: 1.2027e-03
# conv_ab1.weight,   	norm: 2.9234e+00, 	update norm: 2.1970e-03 	Update/norm: 7.5151e-04
# conv_ab1.bias,   	norm: 5.6415e-02, 	update norm: 1.1213e-04 	Update/norm: 1.9876e-03
# conv_ab2.weight,   	norm: 1.1981e+00, 	update norm: 6.2086e-04 	Update/norm: 5.1819e-04
# conv_ab2.bias,   	norm: 3.9362e-02, 	update norm: 5.3786e-05 	Update/norm: 1.3665e-03
#
# ... 0.0930... 0.0922... 0.0600
# Iter 40... 0.0820... 0.0840... 0.0728
# Iter 50... 0.0975... 0.0754... 0.0902
# Iteration 60, loss = 0.0664, corrected loss = 30.9047
# Validation loss 36.9389 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-60
# conv_a1.weight,   	norm: 3.0355e+00, 	update norm: 2.6167e-05 	Update/norm: 8.6201e-06
# conv_a1.bias,   	norm: 1.6283e-01, 	update norm: 5.1061e-06 	Update/norm: 3.1358e-05
# conv_b1.weight,   	norm: 2.9445e+00, 	update norm: 3.8419e-05 	Update/norm: 1.3048e-05
# conv_b1.bias,   	norm: 2.1148e-01, 	update norm: 4.4102e-06 	Update/norm: 2.0854e-05
# conv_a2.weight,   	norm: 3.8916e+00, 	update norm: 4.4961e-04 	Update/norm: 1.1553e-04
# conv_a2.bias,   	norm: 1.8910e-01, 	update norm: 1.5970e-05 	Update/norm: 8.4456e-05
# conv_b2.weight,   	norm: 3.8794e+00, 	update norm: 4.3071e-04 	Update/norm: 1.1102e-04
# conv_b2.bias,   	norm: 1.2329e-01, 	update norm: 1.0830e-05 	Update/norm: 8.7845e-05
# conv_ab1.weight,   	norm: 2.9265e+00, 	update norm: 2.0789e-04 	Update/norm: 7.1036e-05
# conv_ab1.bias,   	norm: 5.5254e-02, 	update norm: 6.4545e-06 	Update/norm: 1.1681e-04
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 8.3637e-05 	Update/norm: 6.9763e-05
# conv_ab2.bias,   	norm: 3.9944e-02, 	update norm: 4.0755e-06 	Update/norm: 1.0203e-04
#
# ... 0.0949... 0.0719... 0.0723
# Iter 70... 0.0953... 0.0832... 0.0781
# Iter 80... 0.0677... 0.0768... 0.0918
# Iteration 90, loss = 0.0867, corrected loss = 40.3645
# Validation loss 36.8276 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-90
# conv_a1.weight,   	norm: 3.0355e+00, 	update norm: 1.4945e-05 	Update/norm: 4.9233e-06
# conv_a1.bias,   	norm: 1.6278e-01, 	update norm: 1.8891e-06 	Update/norm: 1.1605e-05
# conv_b1.weight,   	norm: 2.9443e+00, 	update norm: 2.0182e-05 	Update/norm: 6.8548e-06
# conv_b1.bias,   	norm: 2.1150e-01, 	update norm: 1.6771e-06 	Update/norm: 7.9294e-06
# conv_a2.weight,   	norm: 3.8916e+00, 	update norm: 7.2697e-04 	Update/norm: 1.8680e-04
# conv_a2.bias,   	norm: 1.8935e-01, 	update norm: 1.4812e-05 	Update/norm: 7.8223e-05
# conv_b2.weight,   	norm: 3.8797e+00, 	update norm: 3.2828e-04 	Update/norm: 8.4616e-05
# conv_b2.bias,   	norm: 1.2342e-01, 	update norm: 5.2545e-06 	Update/norm: 4.2575e-05
# conv_ab1.weight,   	norm: 2.9266e+00, 	update norm: 1.7274e-04 	Update/norm: 5.9024e-05
# conv_ab1.bias,   	norm: 5.5185e-02, 	update norm: 1.2890e-06 	Update/norm: 2.3357e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 6.5037e-05 	Update/norm: 5.4247e-05
# conv_ab2.bias,   	norm: 4.0009e-02, 	update norm: 1.2852e-06 	Update/norm: 3.2123e-05
#
# ... 0.0885... 0.0755... 0.0884
# Iter 100... 0.0970... 0.0698... 0.0791
# Iter 110... 0.0709... 0.0732... 0.0557
# Iteration 120, loss = 0.0808, corrected loss = 37.6048
# Validation loss 36.8344 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-120
# conv_a1.weight,   	norm: 3.0354e+00, 	update norm: 1.3066e-05 	Update/norm: 4.3044e-06
# conv_a1.bias,   	norm: 1.6275e-01, 	update norm: 1.6077e-06 	Update/norm: 9.8784e-06
# conv_b1.weight,   	norm: 2.9441e+00, 	update norm: 2.0744e-05 	Update/norm: 7.0458e-06
# conv_b1.bias,   	norm: 2.1150e-01, 	update norm: 1.5832e-06 	Update/norm: 7.4853e-06
# conv_a2.weight,   	norm: 3.8921e+00, 	update norm: 9.0604e-04 	Update/norm: 2.3279e-04
# conv_a2.bias,   	norm: 1.8955e-01, 	update norm: 1.5108e-05 	Update/norm: 7.9705e-05
# conv_b2.weight,   	norm: 3.8797e+00, 	update norm: 1.4309e-04 	Update/norm: 3.6880e-05
# conv_b2.bias,   	norm: 1.2351e-01, 	update norm: 5.5695e-06 	Update/norm: 4.5094e-05
# conv_ab1.weight,   	norm: 2.9265e+00, 	update norm: 1.6604e-04 	Update/norm: 5.6736e-05
# conv_ab1.bias,   	norm: 5.5176e-02, 	update norm: 1.2263e-06 	Update/norm: 2.2225e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 6.0444e-05 	Update/norm: 5.0416e-05
# conv_ab2.bias,   	norm: 4.0043e-02, 	update norm: 1.0878e-06 	Update/norm: 2.7165e-05
#
# ... 0.0747... 0.0858... 0.0697
# Iter 130... 0.0613... 0.0827... 0.0948
# Iter 140... 0.0954... 0.0674... 0.0761
# Iteration 150, loss = 0.0924, corrected loss = 42.9800
# Validation loss 36.8284 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-150
# conv_a1.weight,   	norm: 3.0354e+00, 	update norm: 1.2258e-05 	Update/norm: 4.0384e-06
# conv_a1.bias,   	norm: 1.6271e-01, 	update norm: 1.4868e-06 	Update/norm: 9.1377e-06
# conv_b1.weight,   	norm: 2.9439e+00, 	update norm: 1.9093e-05 	Update/norm: 6.4856e-06
# conv_b1.bias,   	norm: 2.1151e-01, 	update norm: 1.6560e-06 	Update/norm: 7.8295e-06
# conv_a2.weight,   	norm: 3.8929e+00, 	update norm: 7.5935e-04 	Update/norm: 1.9506e-04
# conv_a2.bias,   	norm: 1.8978e-01, 	update norm: 1.4416e-05 	Update/norm: 7.5963e-05
# conv_b2.weight,   	norm: 3.8797e+00, 	update norm: 1.5636e-04 	Update/norm: 4.0301e-05
# conv_b2.bias,   	norm: 1.2360e-01, 	update norm: 4.7478e-06 	Update/norm: 3.8413e-05
# conv_ab1.weight,   	norm: 2.9264e+00, 	update norm: 1.5465e-04 	Update/norm: 5.2846e-05
# conv_ab1.bias,   	norm: 5.5164e-02, 	update norm: 1.2251e-06 	Update/norm: 2.2208e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 5.4186e-05 	Update/norm: 4.5196e-05
# conv_ab2.bias,   	norm: 4.0078e-02, 	update norm: 9.9093e-07 	Update/norm: 2.4725e-05
#
# ... 0.0660... 0.0866... 0.0762
# Iter 160.
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-162
# (Epoch time: 28.37 minutes. Total epochs: 1)
# .. 0.0770... 0.0540... 0.0804
# Iter 170... 0.0653... 0.0608... 0.0863
# Iteration 180, loss = 0.0801, corrected loss = 37.2540
# Validation loss 36.8279 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-180
# conv_a1.weight,   	norm: 3.0354e+00, 	update norm: 9.0847e-06 	Update/norm: 2.9929e-06
# conv_a1.bias,   	norm: 1.6268e-01, 	update norm: 1.2827e-06 	Update/norm: 7.8847e-06
# conv_b1.weight,   	norm: 2.9438e+00, 	update norm: 1.7512e-05 	Update/norm: 5.9489e-06
# conv_b1.bias,   	norm: 2.1151e-01, 	update norm: 1.6010e-06 	Update/norm: 7.5691e-06
# conv_a2.weight,   	norm: 3.8935e+00, 	update norm: 4.3961e-04 	Update/norm: 1.1291e-04
# conv_a2.bias,   	norm: 1.8998e-01, 	update norm: 1.2573e-05 	Update/norm: 6.6179e-05
# conv_b2.weight,   	norm: 3.8797e+00, 	update norm: 1.3487e-04 	Update/norm: 3.4762e-05
# conv_b2.bias,   	norm: 1.2368e-01, 	update norm: 4.0971e-06 	Update/norm: 3.3127e-05
# conv_ab1.weight,   	norm: 2.9263e+00, 	update norm: 1.3109e-04 	Update/norm: 4.4798e-05
# conv_ab1.bias,   	norm: 5.5155e-02, 	update norm: 1.0388e-06 	Update/norm: 1.8834e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 4.3775e-05 	Update/norm: 3.6513e-05
# conv_ab2.bias,   	norm: 4.0107e-02, 	update norm: 8.1211e-07 	Update/norm: 2.0249e-05
#
# ... 0.0674... 0.0704... 0.0807
# Iter 190... 0.0740... 0.0908... 0.0611
# Iter 200... 0.0786... 0.0620... 0.0706
# Iteration 210, loss = 0.0711, corrected loss = 33.0911
# Validation loss 36.8772 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-210
# conv_a1.weight,   	norm: 3.0354e+00, 	update norm: 7.8822e-06 	Update/norm: 2.5968e-06
# conv_a1.bias,   	norm: 1.6265e-01, 	update norm: 1.1205e-06 	Update/norm: 6.8888e-06
# conv_b1.weight,   	norm: 2.9437e+00, 	update norm: 1.1583e-05 	Update/norm: 3.9350e-06
# conv_b1.bias,   	norm: 2.1151e-01, 	update norm: 1.2796e-06 	Update/norm: 6.0497e-06
# conv_a2.weight,   	norm: 3.8936e+00, 	update norm: 2.3875e-04 	Update/norm: 6.1319e-05
# conv_a2.bias,   	norm: 1.9015e-01, 	update norm: 1.0233e-05 	Update/norm: 5.3815e-05
# conv_b2.weight,   	norm: 3.8797e+00, 	update norm: 7.1753e-05 	Update/norm: 1.8494e-05
# conv_b2.bias,   	norm: 1.2376e-01, 	update norm: 3.3560e-06 	Update/norm: 2.7118e-05
# conv_ab1.weight,   	norm: 2.9263e+00, 	update norm: 1.0249e-04 	Update/norm: 3.5025e-05
# conv_ab1.bias,   	norm: 5.5147e-02, 	update norm: 8.6984e-07 	Update/norm: 1.5773e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 3.3655e-05 	Update/norm: 2.8072e-05
# conv_ab2.bias,   	norm: 4.0129e-02, 	update norm: 6.6310e-07 	Update/norm: 1.6524e-05
#
# ... 0.0800... 0.0647... 0.0800
# Iter 220... 0.0666... 0.0645... 0.0666
# Iter 230... 0.0882... 0.0676... 0.0657
# Iteration 240, loss = 0.0690, corrected loss = 32.1079
# Validation loss 36.7790 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-240
# conv_a1.weight,   	norm: 3.0354e+00, 	update norm: 7.0643e-06 	Update/norm: 2.3273e-06
# conv_a1.bias,   	norm: 1.6263e-01, 	update norm: 9.5023e-07 	Update/norm: 5.8429e-06
# conv_b1.weight,   	norm: 2.9436e+00, 	update norm: 1.3902e-05 	Update/norm: 4.7227e-06
# conv_b1.bias,   	norm: 2.1151e-01, 	update norm: 9.4532e-07 	Update/norm: 4.4694e-06
# conv_a2.weight,   	norm: 3.8937e+00, 	update norm: 2.4816e-04 	Update/norm: 6.3732e-05
# conv_a2.bias,   	norm: 1.9032e-01, 	update norm: 9.2381e-06 	Update/norm: 4.8540e-05
# conv_b2.weight,   	norm: 3.8797e+00, 	update norm: 1.1955e-04 	Update/norm: 3.0814e-05
# conv_b2.bias,   	norm: 1.2381e-01, 	update norm: 2.7175e-06 	Update/norm: 2.1949e-05
# conv_ab1.weight,   	norm: 2.9263e+00, 	update norm: 1.0507e-04 	Update/norm: 3.5907e-05
# conv_ab1.bias,   	norm: 5.5138e-02, 	update norm: 8.6321e-07 	Update/norm: 1.5655e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 3.2509e-05 	Update/norm: 2.7116e-05
# conv_ab2.bias,   	norm: 4.0149e-02, 	update norm: 6.0722e-07 	Update/norm: 1.5124e-05
#
# ... 0.0806... 0.1141... 0.0617
# Iter 250... 0.1118... 0.1029... 0.0604
# Iter 260... 0.0806... 0.0834... 0.0530
# Iteration 270, loss = 0.0803, corrected loss = 37.3710
# Validation loss 36.8911 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-270
# conv_a1.weight,   	norm: 3.0354e+00, 	update norm: 8.3934e-06 	Update/norm: 2.7652e-06
# conv_a1.bias,   	norm: 1.6261e-01, 	update norm: 1.1837e-06 	Update/norm: 7.2795e-06
# conv_b1.weight,   	norm: 2.9435e+00, 	update norm: 1.2995e-05 	Update/norm: 4.4150e-06
# conv_b1.bias,   	norm: 2.1150e-01, 	update norm: 1.0425e-06 	Update/norm: 4.9288e-06
# conv_a2.weight,   	norm: 3.8937e+00, 	update norm: 2.8673e-04 	Update/norm: 7.3638e-05
# conv_a2.bias,   	norm: 1.9045e-01, 	update norm: 8.3659e-06 	Update/norm: 4.3927e-05
# conv_b2.weight,   	norm: 3.8796e+00, 	update norm: 9.9866e-05 	Update/norm: 2.5741e-05
# conv_b2.bias,   	norm: 1.2388e-01, 	update norm: 3.0822e-06 	Update/norm: 2.4881e-05
# conv_ab1.weight,   	norm: 2.9263e+00, 	update norm: 1.1500e-04 	Update/norm: 3.9297e-05
# conv_ab1.bias,   	norm: 5.5128e-02, 	update norm: 1.0412e-06 	Update/norm: 1.8887e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 3.2483e-05 	Update/norm: 2.7094e-05
# conv_ab2.bias,   	norm: 4.0165e-02, 	update norm: 6.1840e-07 	Update/norm: 1.5396e-05
#
# ... 0.0595... 0.0668... 0.0697
# Iter 280... 0.0785... 0.0688... 0.1000
# Iter 290... 0.0729... 0.0911... 0.0925
# Iteration 300, loss = 0.0851, corrected loss = 39.5962
# Validation loss 36.7739 over 81 frames
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-300
# conv_a1.weight,   	norm: 3.0353e+00, 	update norm: 3.3359e-06 	Update/norm: 1.0990e-06
# conv_a1.bias,   	norm: 1.6259e-01, 	update norm: 9.4032e-07 	Update/norm: 5.7833e-06
# conv_b1.weight,   	norm: 2.9434e+00, 	update norm: 1.2206e-05 	Update/norm: 4.1468e-06
# conv_b1.bias,   	norm: 2.1150e-01, 	update norm: 1.5093e-06 	Update/norm: 7.1362e-06
# conv_a2.weight,   	norm: 3.8937e+00, 	update norm: 1.6314e-04 	Update/norm: 4.1898e-05
# conv_a2.bias,   	norm: 1.9057e-01, 	update norm: 4.8180e-06 	Update/norm: 2.5282e-05
# conv_b2.weight,   	norm: 3.8796e+00, 	update norm: 7.0839e-05 	Update/norm: 1.8259e-05
# conv_b2.bias,   	norm: 1.2394e-01, 	update norm: 3.4234e-06 	Update/norm: 2.7622e-05
# conv_ab1.weight,   	norm: 2.9263e+00, 	update norm: 6.1800e-05 	Update/norm: 2.1119e-05
# conv_ab1.bias,   	norm: 5.5117e-02, 	update norm: 6.9759e-07 	Update/norm: 1.2656e-05
# conv_ab2.weight,   	norm: 1.1989e+00, 	update norm: 1.5915e-05 	Update/norm: 1.3274e-05
# conv_ab2.bias,   	norm: 4.0180e-02, 	update norm: 3.5018e-07 	Update/norm: 8.7151e-06
#
# ... 0.0796... 0.0699... 0.0811
# Iter 310... 0.0950... 0.0831... 0.0945
# Iter 320... 0.0799
# model saved to model_checkpoints/Model 23 (2,2 layer, Residual+PixNorm) Run 0/Model 23 (2,2 layer, Residual+PixNorm) Run 0-324

# %%
# One last test + visualize results on 1 validation sequence

test(model, post_proc, val_loader, loss_fn, device)
test(ave_model, post_proc, val_loader, loss_fn, device)
# Out:
# Validation loss 36.8405 over 81 frames
# Validation loss 36.8648 over 81 frames
# tensor(36.8648, device='cuda:0')

# %%
with torch.no_grad():
    model.eval()
    for t, (x1, y, x2, mask, max_z) in enumerate(val_loader):
        x1 = x1.to(device=device)  # move to device, e.g. GPU
        y = post_proc(y.to(device=device))
        x2 = x2.to(device=device)
        mask = mask.to(device=device)
        max_z = max_z.to(device=device)
        
        y_hat = post_proc(model((x1, x2)))
        L2_to_ground = loss_fn((y, y_hat, mask, max_z))
        L2_to_ave = loss_fn((post_proc(ave_model((x1,x2))), y_hat, mask, max_z))
        print("Batch %d. Prediction-Real dist: %.5f, Prediction-Ave dist:%.5f"%(t, L2_to_ground.item(), L2_to_ave.item()))
# Out:
# Batch 0. Prediction-Real dist: 39.97477, Prediction-Ave dist:0.34490
# Batch 1. Prediction-Real dist: 43.17880, Prediction-Ave dist:0.27773
# Batch 2. Prediction-Real dist: 35.92266, Prediction-Ave dist:0.31585
# Batch 3. Prediction-Real dist: 38.08811, Prediction-Ave dist:0.35413
# Batch 4. Prediction-Real dist: 40.24942, Prediction-Ave dist:0.29554
# Batch 5. Prediction-Real dist: 36.82784, Prediction-Ave dist:0.37018
# Batch 6. Prediction-Real dist: 38.00856, Prediction-Ave dist:0.29072
# Batch 7. Prediction-Real dist: 37.07455, Prediction-Ave dist:0.35454
# Batch 8. Prediction-Real dist: 40.07668, Prediction-Ave dist:0.27475
# Batch 9. Prediction-Real dist: 37.25634, Prediction-Ave dist:0.29876
# Batch 10. Prediction-Real dist: 38.51016, Prediction-Ave dist:0.29280
# Batch 11. Prediction-Real dist: 37.30344, Prediction-Ave dist:0.26493
# Batch 12. Prediction-Real dist: 37.54470, Prediction-Ave dist:0.26173
# Batch 13. Prediction-Real dist: 40.27461, Prediction-Ave dist:0.27673
# Batch 14. Prediction-Real dist: 35.57074, Prediction-Ave dist:0.29338
# Batch 15. Prediction-Real dist: 43.94503, Prediction-Ave dist:0.26242
# Batch 16. Prediction-Real dist: 35.17585, Prediction-Ave dist:0.18286
# Batch 17. Prediction-Real dist: 37.37737, Prediction-Ave dist:0.25400
# Batch 18. Prediction-Real dist: 40.19065, Prediction-Ave dist:0.28360
# Batch 19. Prediction-Real dist: 32.28151, Prediction-Ave dist:0.30124
# Batch 20. Prediction-Real dist: 33.39391, Prediction-Ave dist:0.46507

# %%
val_seq = TAVR_Sequence("__valid", preproc=preproc_type)
with torch.no_grad():
    model.eval()
    ave_frames = [post_proc(val_seq[0][0].to(device=device))]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:].to(device=device), val_seq[0][i][None,:].to(device=device)))
        ave_frames += [post_proc(ave_frame[0][0]),  post_proc(val_seq[0][i].to(device=device))]
    ave_frames += [post_proc(val_seq[0][9].to(device=device))]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
