# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test
from Models.basic_models import average_model
from Models.two_layer_concat import two_layer_concat

set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)


validation = TAVR_3_Frame("__valid")
val_loader = tavr_dataloader(validation, batch_size=4, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train")
train_loader = tavr_dataloader(training, batch_size=8, shuffle=True, num_workers=2)


ave_model = average_model()
model = two_layer_concat(standardize_slice=True)
loss_fn = batch_l2_loss()
# Out:
# using device: cpu

# %%
learning_rate = 1e-5
momentum = 0.90
reg = 1e-7

optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=reg, nesterov=True)

# %%
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3, lr_decay=0.8)
# Out:
# ****Epoch 0 Iteration 0, loss = 304.7264
# Validation loss 250.0459 over 81 frames
# conv_a1.weight,   	norm: 3.9261e+00, 	update norm: 2.1340e-02 	Update/norm: 5.4355e-03
# conv_a1.bias,   	norm: 2.9904e-01, 	update norm: 1.4460e-04 	Update/norm: 4.8354e-04
# conv_b1.weight,   	norm: 3.7868e+00, 	update norm: 1.2698e-02 	Update/norm: 3.3531e-03
# conv_b1.bias,   	norm: 2.9479e-01, 	update norm: 9.7706e-05 	Update/norm: 3.3144e-04
# final.weight,   	norm: 1.5098e+00, 	update norm: 1.5807e-02 	Update/norm: 1.0470e-02
# final.bias,   	norm: 9.5120e-02, 	update norm: 2.5293e-04 	Update/norm: 2.6591e-03
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 75.6211
# Validation loss 74.6139 over 81 frames
# conv_a1.weight,   	norm: 3.8945e+00, 	update norm: 4.6399e-03 	Update/norm: 1.1914e-03
# conv_a1.bias,   	norm: 2.9987e-01, 	update norm: 7.7487e-05 	Update/norm: 2.5841e-04
# conv_b1.weight,   	norm: 3.7779e+00, 	update norm: 4.3268e-03 	Update/norm: 1.1453e-03
# conv_b1.bias,   	norm: 2.9534e-01, 	update norm: 3.1506e-05 	Update/norm: 1.0668e-04
# final.weight,   	norm: 1.4009e+00, 	update norm: 5.7772e-03 	Update/norm: 4.1239e-03
# final.bias,   	norm: 9.9959e-02, 	update norm: 8.3566e-05 	Update/norm: 8.3600e-04
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 66.1303
# Validation loss 62.4014 over 81 frames
# conv_a1.weight,   	norm: 3.8707e+00, 	update norm: 2.8827e-03 	Update/norm: 7.4475e-04
# conv_a1.bias,   	norm: 3.0036e-01, 	update norm: 3.9192e-05 	Update/norm: 1.3049e-04
# conv_b1.weight,   	norm: 3.7680e+00, 	update norm: 1.4808e-03 	Update/norm: 3.9299e-04
# conv_b1.bias,   	norm: 2.9550e-01, 	update norm: 1.0070e-05 	Update/norm: 3.4078e-05
# final.weight,   	norm: 1.3129e+00, 	update norm: 3.8331e-03 	Update/norm: 2.9195e-03
# final.bias,   	norm: 1.0163e-01, 	update norm: 2.7433e-05 	Update/norm: 2.6992e-04
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 1 Iteration 0, loss = 62.8956
# Validation loss 57.9849 over 81 frames
# conv_a1.weight,   	norm: 3.8576e+00, 	update norm: 2.2567e-03 	Update/norm: 5.8501e-04
# conv_a1.bias,   	norm: 3.0056e-01, 	update norm: 2.9780e-05 	Update/norm: 9.9082e-05
# conv_b1.weight,   	norm: 3.7633e+00, 	update norm: 1.0272e-03 	Update/norm: 2.7296e-04
# conv_b1.bias,   	norm: 2.9558e-01, 	update norm: 6.7268e-06 	Update/norm: 2.2758e-05
# final.weight,   	norm: 1.2641e+00, 	update norm: 2.9411e-03 	Update/norm: 2.3267e-03
# final.bias,   	norm: 1.0208e-01, 	update norm: 1.1161e-05 	Update/norm: 1.0933e-04
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 49.5488
# Validation loss 53.9204 over 81 frames
# conv_a1.weight,   	norm: 3.8426e+00, 	update norm: 1.7867e-03 	Update/norm: 4.6498e-04
# conv_a1.bias,   	norm: 3.0074e-01, 	update norm: 2.0739e-05 	Update/norm: 6.8959e-05
# conv_b1.weight,   	norm: 3.7584e+00, 	update norm: 7.7594e-04 	Update/norm: 2.0645e-04
# conv_b1.bias,   	norm: 2.9567e-01, 	update norm: 4.5039e-06 	Update/norm: 1.5233e-05
# final.weight,   	norm: 1.2048e+00, 	update norm: 2.3261e-03 	Update/norm: 1.9307e-03
# final.bias,   	norm: 1.0221e-01, 	update norm: 4.0010e-06 	Update/norm: 3.9144e-05
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 53.5144
# Validation loss 51.1458 over 81 frames
# conv_a1.weight,   	norm: 3.8309e+00, 	update norm: 1.3302e-03 	Update/norm: 3.4724e-04
# conv_a1.bias,   	norm: 3.0084e-01, 	update norm: 1.3576e-05 	Update/norm: 4.5126e-05
# conv_b1.weight,   	norm: 3.7546e+00, 	update norm: 6.2271e-04 	Update/norm: 1.6585e-04
# conv_b1.bias,   	norm: 2.9574e-01, 	update norm: 4.2021e-06 	Update/norm: 1.4209e-05
# final.weight,   	norm: 1.1565e+00, 	update norm: 1.8187e-03 	Update/norm: 1.5727e-03
# final.bias,   	norm: 1.0204e-01, 	update norm: 1.1168e-05 	Update/norm: 1.0945e-04
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 2 Iteration 0, loss = 44.8213
# Validation loss 49.6120 over 81 frames
# conv_a1.weight,   	norm: 3.8241e+00, 	update norm: 1.1910e-03 	Update/norm: 3.1145e-04
# conv_a1.bias,   	norm: 3.0089e-01, 	update norm: 1.2102e-05 	Update/norm: 4.0221e-05
# conv_b1.weight,   	norm: 3.7523e+00, 	update norm: 5.6368e-04 	Update/norm: 1.5022e-04
# conv_b1.bias,   	norm: 2.9578e-01, 	update norm: 4.0143e-06 	Update/norm: 1.3572e-05
# final.weight,   	norm: 1.1275e+00, 	update norm: 1.6605e-03 	Update/norm: 1.4726e-03
# final.bias,   	norm: 1.0186e-01, 	update norm: 8.4862e-06 	Update/norm: 8.3316e-05
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 50.2601
# Validation loss 48.0006 over 81 frames
# conv_a1.weight,   	norm: 3.8160e+00, 	update norm: 9.5647e-04 	Update/norm: 2.5065e-04
# conv_a1.bias,   	norm: 3.0094e-01, 	update norm: 9.9007e-06 	Update/norm: 3.2900e-05
# conv_b1.weight,   	norm: 3.7496e+00, 	update norm: 4.5247e-04 	Update/norm: 1.2067e-04
# conv_b1.bias,   	norm: 2.9583e-01, 	update norm: 3.2477e-06 	Update/norm: 1.0978e-05
# final.weight,   	norm: 1.0927e+00, 	update norm: 1.3954e-03 	Update/norm: 1.2769e-03
# final.bias,   	norm: 1.0156e-01, 	update norm: 9.7454e-06 	Update/norm: 9.5954e-05
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 46.3732
# Validation loss 46.7510 over 81 frames
# conv_a1.weight,   	norm: 3.8094e+00, 	update norm: 7.6575e-04 	Update/norm: 2.0101e-04
# conv_a1.bias,   	norm: 3.0097e-01, 	update norm: 7.6945e-06 	Update/norm: 2.5566e-05
# conv_b1.weight,   	norm: 3.7473e+00, 	update norm: 4.1294e-04 	Update/norm: 1.1020e-04
# conv_b1.bias,   	norm: 2.9586e-01, 	update norm: 2.9753e-06 	Update/norm: 1.0056e-05
# final.weight,   	norm: 1.0637e+00, 	update norm: 1.1818e-03 	Update/norm: 1.1110e-03
# final.bias,   	norm: 1.0124e-01, 	update norm: 7.7933e-06 	Update/norm: 7.6982e-05
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80

# %%
# Reset the learning rate, stop lr decay, train 3 more epochs
optimizer.param_groups[0]['lr'] = 1e-5
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3)
# Out:
# ****Epoch 0 Iteration 0, loss = 46.0644
# Validation loss 46.0817 over 81 frames
# conv_a1.weight,   	norm: 3.8056e+00, 	update norm: 1.2793e-03 	Update/norm: 3.3617e-04
# conv_a1.bias,   	norm: 3.0098e-01, 	update norm: 1.2813e-05 	Update/norm: 4.2570e-05
# conv_b1.weight,   	norm: 3.7459e+00, 	update norm: 6.7003e-04 	Update/norm: 1.7887e-04
# conv_b1.bias,   	norm: 2.9588e-01, 	update norm: 4.8381e-06 	Update/norm: 1.6352e-05
# final.weight,   	norm: 1.0468e+00, 	update norm: 2.0218e-03 	Update/norm: 1.9314e-03
# final.bias,   	norm: 1.0103e-01, 	update norm: 1.8157e-05 	Update/norm: 1.7972e-04
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 44.9104
# Validation loss 44.4603 over 81 frames
# conv_a1.weight,   	norm: 3.7962e+00, 	update norm: 1.1447e-03 	Update/norm: 3.0154e-04
# conv_a1.bias,   	norm: 3.0102e-01, 	update norm: 1.0483e-05 	Update/norm: 3.4825e-05
# conv_b1.weight,   	norm: 3.7424e+00, 	update norm: 5.8040e-04 	Update/norm: 1.5509e-04
# conv_b1.bias,   	norm: 2.9592e-01, 	update norm: 5.5512e-06 	Update/norm: 1.8759e-05
# final.weight,   	norm: 1.0047e+00, 	update norm: 1.8939e-03 	Update/norm: 1.8850e-03
# final.bias,   	norm: 1.0043e-01, 	update norm: 2.0392e-05 	Update/norm: 2.0305e-04
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 45.5062
# Validation loss 43.1722 over 81 frames
# conv_a1.weight,   	norm: 3.7883e+00, 	update norm: 9.9367e-04 	Update/norm: 2.6230e-04
# conv_a1.bias,   	norm: 3.0104e-01, 	update norm: 9.7400e-06 	Update/norm: 3.2354e-05
# conv_b1.weight,   	norm: 3.7394e+00, 	update norm: 4.8108e-04 	Update/norm: 1.2865e-04
# conv_b1.bias,   	norm: 2.9594e-01, 	update norm: 4.3311e-06 	Update/norm: 1.4635e-05
# final.weight,   	norm: 9.6839e-01, 	update norm: 1.6760e-03 	Update/norm: 1.7307e-03
# final.bias,   	norm: 9.9747e-02, 	update norm: 1.8254e-05 	Update/norm: 1.8300e-04
#
# Iter 60... ... ...
# Iter 70... ... ...
# Iter 80
# ****Epoch 1 Iteration 0, loss = 39.8042
# Validation loss 42.4977 over 81 frames
# conv_a1.weight,   	norm: 3.7835e+00, 	update norm: 8.6752e-04 	Update/norm: 2.2929e-04
# conv_a1.bias,   	norm: 3.0105e-01, 	update norm: 8.4473e-06 	Update/norm: 2.8059e-05
# conv_b1.weight,   	norm: 3.7376e+00, 	update norm: 4.3158e-04 	Update/norm: 1.1547e-04
# conv_b1.bias,   	norm: 2.9595e-01, 	update norm: 4.5099e-06 	Update/norm: 1.5239e-05
# final.weight,   	norm: 9.4667e-01, 	update norm: 1.5462e-03 	Update/norm: 1.6333e-03
# final.bias,   	norm: 9.9283e-02, 	update norm: 2.0444e-05 	Update/norm: 2.0592e-04
#
# Iter 0... ... ...
# Iter 10... ... ...
# Iter 20... ... ...
# Iteration 30, loss = 45.4597
# Validation loss 41.5005 over 81 frames
# conv_a1.weight,   	norm: 3.7775e+00, 	update norm: 7.2974e-04 	Update/norm: 1.9318e-04
# conv_a1.bias,   	norm: 3.0106e-01, 	update norm: 7.2123e-06 	Update/norm: 2.3957e-05
# conv_b1.weight,   	norm: 3.7352e+00, 	update norm: 3.5128e-04 	Update/norm: 9.4047e-05
# conv_b1.bias,   	norm: 2.9596e-01, 	update norm: 5.1751e-06 	Update/norm: 1.7486e-05
# final.weight,   	norm: 9.1875e-01, 	update norm: 1.4278e-03 	Update/norm: 1.5541e-03
# final.bias,   	norm: 9.8584e-02, 	update norm: 2.5563e-05 	Update/norm: 2.5930e-04
#
# Iter 30... ... ...
# Iter 40... ... ...
# Iter 50... ... ...
# Iteration 60, loss = 41.1775
# Validation loss 40.9669 over 81 frames
# conv_a1.weight,   	norm: 3.7722e+00, 	update norm: 6.6167e-04 	Update/norm: 1.7541e-04
# conv_a1.bias,   	norm: 3.0106e-01, 	update norm: 5.8367e-06 	Update/norm: 1.9388e-05
# conv_b1.weight,   	norm: 3.7332e+00, 	update norm: 3.3112e-04 	Update/norm: 8.8697e-05
# conv_b1.bias,   	norm: 2.9596e-01, 	update norm: 4.4543e-06 	Update/norm: 1.5050e-05
# final.weight,   	norm: 8.9491e-01, 	update norm: 1.3008e-03 	Update/norm: 1.4535e-03
# final.bias,   	norm: 9.7839e-02, 	update norm: 2.2918e-05 	Update/norm: 2.3424e-04
#
# Iter 60... ... ...
# Iter 70... .

# %%
# One last test + visualize results on 1 validation sequence
val_seq = TAVR_Sequence("__valid")
test(model, val_loader, loss_fn, device)
test(ave_model, val_loader, loss_fn, device)

with torch.no_grad():
    model.eval()
    ave_frames = [val_seq[0][0]]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:], val_seq[0][i][None,:]))
        ave_frames += [ave_frame[0][0],  val_seq[0][i]]
    ave_frames += [val_seq[0][9]]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)

# %%
train(model, optimizer, train_loader, val_loader, loss_fn, device, 
         epochs=3, print_every=30, print_level=3)
