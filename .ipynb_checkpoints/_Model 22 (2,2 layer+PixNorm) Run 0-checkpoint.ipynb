# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import utils.tavr_torch as tavr_torch
from utils.tavr_torch import TAVR_3_Frame, TAVR_1_Frame, TAVR_Sequence, tavr_dataloader
from utils.visualization import display_grid, z_stretch, visualize_frame, set_figsize, get_central_slices
from utils.loss_functions import batch_l2_loss
from utils.run_model import train, test, save, load, get_loss_history
from Models.basic_models import average_model, two_layer_basic, post_process
from Models.nm_layer import nm_layer_net

set_figsize(20, 15)
# Out:
# Training directory found, 36 series
# Validation directory found, 6 series
# Testing directory found, 10 series

# %%
USE_GPU = True
dtype = torch.float32 # we will be using float throughout this tutorial
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print('using device:', device)

# "Pixl", "Slice", or "None"
preproc_type = "pixel"

validation = TAVR_3_Frame("__valid", preproc=preproc_type, preload=False)
val_loader = tavr_dataloader(validation, batch_size=4, shuffle=True, num_workers=2)
training = TAVR_3_Frame("__train", preproc=preproc_type, preload=False)
train_loader = tavr_dataloader(training,batch_size=4, shuffle=True, num_workers=2)


ave_model = average_model()
model = nm_layer_net([4,8],[4,1])
post_proc = post_process(kind=preproc_type).to(device=device)
loss_fn = batch_l2_loss()

# CHANGE TO NAME OF JUPYTER NOTEBOOK
model_name = "Model 22 (2,2 layer+PixNorm) Run 0"
# Out:
# using device: cuda

# %%
learning_rate = 1e-3
reg = 1e-7

optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

# %%
LOAD = False
iteration_num = -1

if LOAD:
    load(model_name, iteration_num, model, optimizer)
    loss_history = get_loss_history(model_name)
    model.to(device=device)
    # I don't know why these lines are necessary
    # or even what the hell they do
    # but they are
    if str(device) == 'cuda':
        for state in optimizer.state.values():
            for k, v in state.items():
                state[k] = v.cuda()
else:
    loss_history = None

# %%
# If multiple GPU
# model = nn.DataParallel(model)

# %%
train(model, post_proc, optimizer, train_loader, val_loader, loss_fn, device, 
         model_name, loss_history,
          epochs=2, print_every=30, print_level=4, lr_decay=1)
# Out:
# Iteration 0, loss = 0.9038, corrected loss = 420.5723
# Validation loss 392.3417 over 81 frames
# model saved to model_checkpoints/Model 22 (2,2 layer+PixNorm) Run 0/Model 22 (2,2 layer+PixNorm) Run 0-0
# conv_a1.weight,   	norm: 2.4860e+00, 	update norm: 1.0391e-02 	Update/norm: 4.1799e-03
# conv_a1.bias,   	norm: 2.4290e-01, 	update norm: 1.9997e-03 	Update/norm: 8.2328e-03
# conv_b1.weight,   	norm: 3.1216e+00, 	update norm: 1.0391e-02 	Update/norm: 3.3288e-03
# conv_b1.bias,   	norm: 1.8838e-01, 	update norm: 1.9992e-03 	Update/norm: 1.0613e-02
# conv_a2.weight,   	norm: 4.0757e+00, 	update norm: 2.9264e-02 	Update/norm: 7.1802e-03
# conv_a2.bias,   	norm: 1.7542e-01, 	update norm: 2.8270e-03 	Update/norm: 1.6116e-02
# conv_b2.weight,   	norm: 3.8730e+00, 	update norm: 2.9348e-02 	Update/norm: 7.5777e-03
# conv_b2.bias,   	norm: 1.8387e-01, 	update norm: 2.8282e-03 	Update/norm: 1.5381e-02
# conv_ab1.weight,   	norm: 2.7399e+00, 	update norm: 4.1438e-02 	Update/norm: 1.5124e-02
# conv_ab1.bias,   	norm: 2.7138e-02, 	update norm: 2.0000e-03 	Update/norm: 7.3696e-02
# conv_ab2.weight,   	norm: 1.5769e+00, 	update norm: 1.0392e-02 	Update/norm: 6.5902e-03
# conv_ab2.bias,   	norm: 2.0740e-02, 	update norm: 1.0000e-03 	Update/norm: 4.8215e-02
#
# ... 0.7826... 0.8706... 0.7894
# Iter 10... 0.7842... 0.7902... 0.6316
# Iter 20... 0.6832... 0.8401... 0.7499
# Iteration 30, loss = 0.7927, corrected loss = 368.8593
# Validation loss 362.3846 over 81 frames
# model saved to model_checkpoints/Model 22 (2,2 layer+PixNorm) Run 0/Model 22 (2,2 layer+PixNorm) Run 0-30
# conv_a1.weight,   	norm: 2.4545e+00, 	update norm: 1.9847e-03 	Update/norm: 8.0861e-04
# conv_a1.bias,   	norm: 2.3707e-01, 	update norm: 8.1946e-04 	Update/norm: 3.4567e-03
# conv_b1.weight,   	norm: 3.1023e+00, 	update norm: 3.0832e-03 	Update/norm: 9.9384e-04
# conv_b1.bias,   	norm: 1.8832e-01, 	update norm: 5.0216e-04 	Update/norm: 2.6665e-03
# conv_a2.weight,   	norm: 4.0496e+00, 	update norm: 1.2629e-02 	Update/norm: 3.1187e-03
# conv_a2.bias,   	norm: 1.8139e-01, 	update norm: 6.9911e-04 	Update/norm: 3.8541e-03
# conv_b2.weight,   	norm: 3.8512e+00, 	update norm: 1.2609e-02 	Update/norm: 3.2739e-03
# conv_b2.bias,   	norm: 1.9173e-01, 	update norm: 4.6209e-04 	Update/norm: 2.4101e-03
# conv_ab1.weight,   	norm: 2.7409e+00, 	update norm: 1.1253e-02 	Update/norm: 4.1057e-03
# conv_ab1.bias,   	norm: 4.3864e-02, 	update norm: 3.2648e-04 	Update/norm: 7.4431e-03
# conv_ab2.weight,   	norm: 1.5688e+00, 	update norm: 1.3079e-03 	Update/norm: 8.3366e-04
# conv_ab2.bias,   	norm: 6.1275e-03, 	update norm: 1.1961e-04 	Update/norm: 1.9520e-02
#
# ... 0.7507... 0.8127... 0.7947
# Iter 40... 0.7944... 0.8311... 0.7062
# Iter 50... 0.7672... 0.7907... 0.6768
# Iteration 60, loss = 0.6171, corrected loss = 287.1426
# Validation loss 359.4949 over 81 frames
# model saved to model_checkpoints/Model 22 (2,2 layer+PixNorm) Run 0/Model 22 (2,2 layer+PixNorm) Run 0-60
# conv_a1.weight,   	norm: 2.4427e+00, 	update norm: 1.4481e-03 	Update/norm: 5.9281e-04
# conv_a1.bias,   	norm: 2.2740e-01, 	update norm: 3.3994e-04 	Update/norm: 1.4949e-03
# conv_b1.weight,   	norm: 3.0830e+00, 	update norm: 2.4003e-03 	Update/norm: 7.7854e-04
# conv_b1.bias,   	norm: 1.9916e-01, 	update norm: 8.2104e-04 	Update/norm: 4.1224e-03
# conv_a2.weight,   	norm: 4.0312e+00, 	update norm: 1.2025e-02 	Update/norm: 2.9830e-03
# conv_a2.bias,   	norm: 1.8120e-01, 	update norm: 2.0611e-04 	Update/norm: 1.1375e-03
# conv_b2.weight,   	norm: 3.8331e+00, 	update norm: 1.0200e-02 	Update/norm: 2.6611e-03
# conv_b2.bias,   	norm: 1.9181e-01, 	update norm: 1.4313e-04 	Update/norm: 7.4618e-04
# conv_ab1.weight,   	norm: 2.7347e+00, 	update norm: 1.1837e-02 	Update/norm: 4.3285e-03
# conv_ab1.bias,   	norm: 4.9070e-02, 	update norm: 1.4370e-04 	Update/norm: 2.9286e-03
# conv_ab2.weight,   	norm: 1.5633e+00, 	update norm: 6.3481e-04 	Update/norm: 4.0606e-04
# conv_ab2.bias,   	norm: 5.4969e-03, 	update norm: 1.3220e-05 	Update/norm: 2.4050e-03
#
# ... 0.7995... 0.6844... 0.6925
# Iter 70... 0.8027... 0.6578... 0.6779
# Iter 80... 0.6735... 0.7344... 0.8463
# Iteration 90, loss = 0.7087, corrected loss = 329.7567
# Validation loss 358.4605 over 81 frames
# model saved to model_checkpoints/Model 22 (2,2 layer+PixNorm) Run 0/Model 22 (2,2 layer+PixNorm) Run 0-90
# conv_a1.weight,   	norm: 2.4346e+00, 	update norm: 1.0846e-03 	Update/norm: 4.4547e-04
# conv_a1.bias,   	norm: 2.2442e-01, 	update norm: 2.2313e-04 	Update/norm: 9.9425e-04
# conv_b1.weight,   	norm: 3.0700e+00, 	update norm: 1.7343e-03 	Update/norm: 5.6494e-04
# conv_b1.bias,   	norm: 2.1072e-01, 	update norm: 7.2286e-04 	Update/norm: 3.4304e-03
# conv_a2.weight,   	norm: 4.0161e+00, 	update norm: 1.4180e-02 	Update/norm: 3.5307e-03
# conv_a2.bias,   	norm: 1.7779e-01, 	update norm: 1.7012e-03 	Update/norm: 9.5689e-03
# conv_b2.weight,   	norm: 3.8322e+00, 	update norm: 7.7076e-03 	Update/norm: 2.0113e-03
# conv_b2.bias,   	norm: 1.9087e-01, 	update norm: 2.6058e-04 	Update/norm: 1.3652e-03
# conv_ab1.weight,   	norm: 2.7346e+00, 	update norm: 1.5243e-02 	Update/norm: 5.5740e-03
# conv_ab1.bias,   	norm: 5.0291e-02, 	update norm: 1.0087e-04 	Update/norm: 2.0057e-03
# conv_ab2.weight,   	norm: 1.5584e+00, 	update norm: 7.7997e-04 	Update/norm: 5.0051e-04
# conv_ab2.bias,   	norm: 6.2664e-03, 	update norm: 2.0418e-05 	Update/norm: 3.2584e-03
#
# ... 0.7884... 0.7035... 0.8677
# Iter 100... 0.8783... 0.7360... 0.7668
# Iter 110... 0.7690... 0.7747... 0.8512
# Iteration 120, loss = 0.7144, corrected loss = 332.4419
# Validation loss 358.0972 over 81 frames
# model saved to model_checkpoints/Model 22 (2,2 layer+PixNorm) Run 0/Model 22 (2,2 layer+PixNorm) Run 0-120
# conv_a1.weight,   	norm: 2.4282e+00, 	update norm: 7.5420e-04 	Update/norm: 3.1060e-04
# conv_a1.bias,   	norm: 2.2220e-01, 	update norm: 1.6161e-04 	Update/norm: 7.2734e-04
# conv_b1.weight,   	norm: 3.0577e+00, 	update norm: 1.2223e-03 	Update/norm: 3.9976e-04
# conv_b1.bias,   	norm: 2.2015e-01, 	update norm: 5.0009e-04 	Update/norm: 2.2716e-03
# conv_a2.weight,   	norm: 4.0010e+00, 	update norm: 8.5257e-03 	Update/norm: 2.1309e-03
# conv_a2.bias,   	norm: 1.6816e-01, 	update norm: 1.0353e-03 	Update/norm: 6.1567e-03
# conv_b2.weight,   	norm: 3.8297e+00, 	update norm: 5.4277e-03 	Update/norm: 1.4173e-03
# conv_b2.bias,   	norm: 1.9145e-01, 	update norm: 3.0148e-04 	Update/norm: 1.5747e-03
# conv_ab1.weight,   	norm: 2.7366e+00, 	update norm: 1.0377e-02 	Update/norm: 3.7922e-03
# conv_ab1.bias,   	norm: 5.0899e-02, 	update norm: 3.3477e-05 	Update/norm: 6.5771e-04
# conv_ab2.weight,   	norm: 1.5530e+00, 	update norm: 9.7403e-04 	Update/norm: 6.2718e-04
# conv_ab2.bias,   	norm: 6.3195e-03, 	update norm: 3.3723e-06 	Update/norm: 5.3363e-04
#
# ... 0.8566... 0.7187... 0.8111
# Iter 130... 0.7319... 0.7899... 0.7270
# Iter 140... 0.7747... 0.7300... 0.7961
# Iteration 150, loss = 0.7176, corrected loss = 333.9329
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process Process-1:
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-13:
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process Process-14:
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/shared/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/Leon/Project/utils/tavr_torch.py", line 285, in collator_3_frame
#     A, B, C, D = torch.zeros(*shape), torch.zeros(*shape), torch.zeros(*shape), torch.zeros(*shape)
# KeyboardInterrupt
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fc3046283c8>>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 347, in __del__
#     def __del__(self):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 178, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 8999) exited unexpectedly with exit code 1.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-84b13b03510b> in <module>()
#       1 train(model, post_proc, optimizer, train_loader, val_loader, loss_fn, device,
#       2          model_name, loss_history,
# ----> 3           epochs=2, print_every=30, print_level=4, lr_decay=1)
#
# ~/Project/utils/run_model.py in train(model, post_proc, optimizer, train_loader, val_loader, loss_fn, device, model_name, loss_history, epochs, print_every, print_level, lr_decay)
#     146                           (loss_history['iteration'], loss.item(), c_loss.item()))
#     147                     loss_history['train_c'].append(c_loss.item())
# --> 148                     valid_loss = test(model, post_proc, val_loader, loss_fn, device)
#     149                     loss_history['valid'].append(valid_loss.item())
#     150                     if str(type(model))[-10:-2] == "Parallel":
#
# ~/Project/utils/run_model.py in test(model, post_proc, loader, loss_fn, device)
#      61             y_hat = model((x1, x2))
#      62             y_hat = post_proc(y_hat)
# ---> 63             loss = loss_fn((y, y_hat, mask, max_z))
#      64
#      65             # Ensure equal weighting between batches of different size
#
# /home/shared/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/Project/utils/loss_functions.py in forward(self, results)
#       8     def forward(self, results):
#       9         y, y_hat, mask, max_z = results
# ---> 10         L2 = (torch.squeeze(y_hat)-y)**2 * mask/(torch.sum(max_z) * 256 * 256)
#      11         L2_total = torch.sqrt(torch.sum(L2))
#      12         return L2_total #, np.sqrt(torch.max(L2).detach().numpy()), L2_total.detach().numpy()
#
# KeyboardInterrupt:

# %%
# One last test + visualize results on 1 validation sequence

test(model, post_proc, val_loader, loss_fn, device)
test(ave_model, post_proc, val_loader, loss_fn, device)

# %%
val_seq = TAVR_Sequence("__valid", preproc=preproc_type)
with torch.no_grad():
    model.eval()
    ave_frames = [post_proc(val_seq[0][0].to(device=device))]
    for i in range(2,9,2):
        ave_frame = model((val_seq[0][i-2][None,:].to(device=device), val_seq[0][i][None,:].to(device=device)))
        ave_frames += [post_proc(ave_frame[0][0]),  post_proc(val_seq[0][i].to(device=device))]
    ave_frames += [post_proc(val_seq[0][9].to(device=device))]
    ave_frames_slices = []
    for f in ave_frames:
        ave_frames_slices += get_central_slices(f)
    set_figsize(6,20)
    display_grid(10, 3, ave_frames_slices)
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
